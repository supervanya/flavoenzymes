# %%
import json
import pandas as pd
import re

# %%
kegg_path = 'export/kegg.json'
brenda_path = 'export/brenda.json'

# %%
csv='kegg_pseudoisomers_Alberty.csv'
df=pd.read_csv(csv, sep='\t', header=1)

# %%
df.columns
df.head()
# Out:
#   !Identifiers:kegg.compound  !Name  !dG0 (kJ/mol)  !nH  !charge  !nMg  !Note
# 0                     C00001  C_h2o         -237.2    2        0     0    NaN
# 1                     C00002  C_atp        -2768.1   12       -4     0    NaN
# 2                     C00002  C_atp        -3258.7   12       -2     1    NaN
# 3                     C00002  C_atp        -3729.3   12        0     2    NaN
# 4                     C00002  C_atp        -2811.5   13       -3     0    NaN

# %%
def read_json_data(path):
    with open(path) as json_file:
        return json.load(json_file)

# %%
kegg_data = read_json_data(kegg_path)
brenda_data = read_json_data(brenda_path)

# %%
enzyme_list = list(kegg_data.values())

# %%
# Example of the BrendaDB:
# brenda_enzymes = {
#             ecNumber: {
#                 'SYSNAME': "...", # should this be an array?
#                 'REACTIONS': [{reaction},],
#                 'NAME': ['...',],
#                 'SUBSTRATE': [{substrate},],
#                 'PRODUCT': [{product},],
#                 'PDB': [{pdb}]
#             },
#         }


#{ec number: [names: 'dfafsfsff'], substrates: [f, f, f,], products: [f,f,f]}

kegg_data['(7Z,10Z)-hexadeca-7,10-dienoyl-[glycerolipid],ferredoxin:oxygen oxidoreductase (13,14 cis-dehydrogenating)']['SUBSTRATE']
# Out:
# ['(7Z,10Z)-hexadeca-7,10-dienoyl-[glycerolipid];',
#  'reduced ferredoxin [iron-sulfur] cluster [CPD:C00138];',
#  'O2 [CPD:C00007];',
#  'H+ [CPD:C00080];',
#  'linoleoyl-[glycerolipid] [CPD:C21529]']

# %%
brenda_substrates=brenda_data['1.14.19.35']['SUBSTRATE']
substrate_set=set()
for substrates in brenda_substrates:
    substrate_set.add(substrates['substrate'])
    
print(substrate_set)
# Out:
# {'2 H+', '2 reduced ferredoxin', 'more', 'a linoleoyl-[glycerolipid]', '2 reduced ferredoxin [iron-sulfur] cluster', 'a (7Z,10Z)-hexadeca-7,10-dienoyl-[glycerolipid]', 'alpha-linoleoyl-[glycerolipid]', 'O2'}

# %%
brenda_products=brenda_data['1.14.19.35']['PRODUCT']
product_set=set()
for products in brenda_products:
    product_set.add(products['product'])
print(product_set)
# Out:
# {'2 oxidized ferredoxin [iron-sulfur] cluster', '2 H2O', 'a (7Z,10Z,13Z)-hexadeca-7,10,13-trienoyl-[glycerolipid]', '2 oxidized ferredoxin', 'an alpha-linolenoyl-[glycerolipid]', '?', 'alpha-linolenoyl-[glycerolipid]'}

# %%
def substrate_mapper(names, substrates, products):
    return names + '\n' + substrates + '\n' + products
    
for enzyme in enzyme_list:
    names=enzyme.get('NAME', [])
    flavoenzyme_names="Flavoenzyme name: "
    substrate_names=enzyme.get('SUBSTRATE', [])
    substrates="substrates: "
    product_names=enzyme.get('PRODUCT', [])
    products="products: "
    for substrate in substrate_names:
        substrates+= substrate
    for product in product_names:
        products+=product
    for name in names:
        flavoenzyme_names+=name[0:]
    flavoenzyme_substrates=substrate_mapper(flavoenzyme_names, substrates, products)
    
    print(flavoenzyme_substrates)
    print ('\n')
# Out:
# Flavoenzyme name: sn-2 acyl-lipid omega-3 desaturase (ferredoxin);FAD7;FAD8
# substrates: (7Z,10Z)-hexadeca-7,10-dienoyl-[glycerolipid];reduced ferredoxin [iron-sulfur] cluster [CPD:C00138];O2 [CPD:C00007];H+ [CPD:C00080];linoleoyl-[glycerolipid] [CPD:C21529]
# products: (7Z,10Z,13Z)-hexadeca-7,10,13-trienoyl-[glycerolipid];oxidized ferredoxin [iron-sulfur] cluster [CPD:C00139];H2O [CPD:C00001];alpha-linolenoyl-[glycerolipid] [CPD:C21531]
#
#
# Flavoenzyme name: thymidylate synthase (FAD);Thy1;ThyX
# substrates: 5,10-methylenetetrahydrofolate [CPD:C00143];dUMP [CPD:C00365];NADPH [CPD:C00005];H+ [CPD:C00080]
# products: dTMP [CPD:C00364];tetrahydrofolate [CPD:C00101];NADP+ [CPD:C00006]
#
#
# Flavoenzyme name: methylenetetrahydrofolate---tRNA-(uracil54-C5)-methyltransferase [NAD(P)H-oxidizing];folate-dependent ribothymidyl synthase;methylenetetrahydrofolate-transfer ribonucleate uracil 5-methyltransferase;5,10-methylenetetrahydrofolate:tRNA-UPsiC (uracil-5-)-methyl-transferase;5,10-methylenetetrahydrofolate:tRNA (uracil-5-)-methyl-transferase;TrmFO;folate/FAD-dependent tRNA T54 methyltransferase;methylenetetrahydrofolate---tRNA-(uracil54-C5)-methyltransferase (FADH2-oxidizing)
# substrates: 5,10-methylenetetrahydrofolate [CPD:C00143];uracil54 in tRNA;NADH [CPD:C00004];NADPH [CPD:C00005];H+ [CPD:C00080]
# products: tetrahydrofolate [CPD:C00101];5-methyluracil54 in tRNA;NAD+ [CPD:C00003];NADP+ [CPD:C00006]
#
#
# Flavoenzyme name: FAD diphosphatase;FAD pyrophosphatase;riboflavin adenine dinucleotide pyrophosphatase;flavin adenine dinucleotide pyrophosphatase;riboflavine adenine dinucleotide pyrophosphatase;flavine adenine dinucleotide pyrophosphatase
# substrates: FAD [CPD:C00016];H2O [CPD:C00001]
# products: AMP [CPD:C00020];FMN [CPD:C00061]
#
#
# Flavoenzyme name: caspase-8;FLICE, FADD-like ICE;MACH;MORT1-associated CED-3 homolog;Mch5;mammalian Ced-3 homolog 5;CASP-8;ICE-like apoptotic protease 5;FADD-homologous ICE/CED-3-like protease;apoptotic cysteine protease;apoptotic protease Mch-5;CAP4
# substrates:
# products:
#
#
# Flavoenzyme name: riboflavin kinase;flavokinase;FK;RFK
# substrates: ATP [CPD:C00002];riboflavin [CPD:C00255]
# products: ADP [CPD:C00008];FMN [CPD:C00061]
#
#
# Flavoenzyme name: FMN reductase (NADH);NADH-FMN reductase;NADH-dependent FMN reductase;NADH:FMN oxidoreductase;NADH:flavin oxidoreductase
# substrates: FMNH2 [CPD:C01847];NAD+ [CPD:C00003]
# products: FMN [CPD:C00061];NADH [CPD:C00004];H+ [CPD:C00080]
#
#
# Flavoenzyme name: 4'-demethylrebeccamycin synthase;arcyriaflavin A N-glycosyltransferase;RebG
# substrates: 4'-O-demethylrebeccamycin [CPD:C19700];H2O [CPD:C00001]
# products: dichloroarcyriaflavin A [CPD:C19699];beta-D-glucose [CPD:C00221]
#
#
# Flavoenzyme name: medium-chain acyl-CoA ligase;fadK (gene name);lvaE (gene name);butyryl-CoA synthetase;fatty acid thiokinase (medium chain);acyl-activating enzyme;fatty acid elongase;fatty acid activating enzyme;fatty acyl coenzyme A synthetase;butyrate---CoA ligase;butyryl-coenzyme A synthetase;L-(+)-3-hydroxybutyryl CoA ligase;short-chain acyl-CoA synthetase;medium-chain acyl-CoA synthetase;butanoate:CoA ligase (AMP-forming)
# substrates: ATP [CPD:C00002];medium-chain fatty acid [CPD:C21925];CoA [CPD:C00010]
# products: AMP [CPD:C00020];diphosphate [CPD:C00013];medium-chain acyl-CoA [CPD:C21926]
#
#
# Flavoenzyme name: riboflavin reductase [NAD(P)H];NAD(P)H-FMN reductase (ambiguous);NAD(P)H-dependent FMN reductase (ambiguous);NAD(P)H:FMN oxidoreductase (ambiguous);NAD(P)H:flavin oxidoreductase (ambiguous);NAD(P)H2 dehydrogenase (FMN) (ambiguous);NAD(P)H2:FMN oxidoreductase (ambiguous);riboflavin mononucleotide reductase (ambiguous);flavine mononucleotide reductase (ambiguous);riboflavin mononucleotide (reduced nicotinamide adenine dinucleotide (phosphate)) reductase;flavin mononucleotide reductase (ambiguous);riboflavine mononucleotide reductase (ambiguous);Fre
# substrates: reduced riboflavin [CPD:C01007];NAD+ [CPD:C00003];NADP+ [CPD:C00006]
# products: riboflavin [CPD:C00255];NADH [CPD:C00004];NADPH [CPD:C00005];H+ [CPD:C00080]
#
#
# Flavoenzyme name: methanesulfonate monooxygenase (NADH);mesylate monooxygenase;mesylate,reduced-FMN:oxygen oxidoreductase;MsmABC;methanesulfonic acid monooxygenase;MSA monooxygenase;MSAMO
# substrates: methanesulfonate [CPD:C11145];NADH [CPD:C00004];H+ [CPD:C00080];O2 [CPD:C00007]
# products: formaldehyde [CPD:C00067];NAD+ [CPD:C00003];sulfite [CPD:C00094];H2O [CPD:C00001]
#
#
# Flavoenzyme name: flavin prenyltransferase;ubiX (gene name);PAD1 (gene name)
# substrates: dimethylallyl phosphate [CPD:C21214];FMNH2 [CPD:C01847]
# products: prenylated FMNH2 [CPD:C21215];phosphate [CPD:C00009]
#
#
# Flavoenzyme name: alkanesulfonate monooxygenase;SsuD;sulfate starvation-induced protein 6;alkanesulfonate,reduced-FMN:oxygen oxidoreductase
# substrates: alkanesulfonate [CPD:C15521];FMNH2 [CPD:C01847];O2 [CPD:C00007]
# products: aldehyde [CPD:C00071];FMN [CPD:C00061];sulfite [CPD:C00094];H2O [CPD:C00001]
#
#
# Flavoenzyme name: methylenetetrahydrofolate reductase [NAD(P)H];methylenetetrahydrofolate (reduced nicotinamide adenine dinucleotide phosphate) reductase;5,10-methylenetetrahydrofolate reductase (NADPH);5,10-methylenetetrahydrofolic acid reductase;5,10-CH2-H4folate reductase;methylenetetrahydrofolate reductase (NADPH2);5-methyltetrahydrofolate:NAD+ oxidoreductase;5-methyltetrahydrofolate:NAD+ oxidoreductase;methylenetetrahydrofolate (reduced riboflavin adenine dinucleotide) reductase;5,10-methylenetetrahydrofolate reductase;methylenetetrahydrofolate reductase;N5,10-methylenetetrahydrofolate reductase;5,10-methylenetetrahydropteroylglutamate reductase;N5,N10-methylenetetrahydrofolate reductase;methylenetetrahydrofolic acid reductase;5-methyltetrahydrofolate:(acceptor) oxidoreductase (incorrect);5,10-methylenetetrahydrofolate reductase (FADH2);MetF;methylenetetrahydrofolate reductase (NADPH);5-methyltetrahydrofolate:NADP+ oxidoreductase
# substrates: 5-methyltetrahydrofolate [CPD:C00440];NAD+ [CPD:C00003];NADP+ [CPD:C00006]
# products: 5,10-methylenetetrahydrofolate [CPD:C00143];NADH [CPD:C00004];NADPH [CPD:C00005];H+ [CPD:C00080]
#
#
# Flavoenzyme name: resorcinol 4-hydroxylase (FADH2);graA (gene name)
# substrates: resorcinol [CPD:C01751];FADH2 [CPD:C01352];O2 [CPD:C00007]
# products: hydroxyquinol [CPD:C02814];FAD [CPD:C00016];H2O [CPD:C00001]
#
#
# Flavoenzyme name: riboflavin phosphotransferase;riboflavine phosphotransferase;glucose-1-phosphate phosphotransferase;G-1-P phosphotransferase;D-glucose-1-phosphate:riboflavin 5'-phosphotransferase
# substrates: alpha-D-glucose 1-phosphate [CPD:C00103];riboflavin [CPD:C00255]
# products: D-glucose [CPD:C00031];FMN [CPD:C00061]
#
#
# Flavoenzyme name: FAD-dependent urate hydroxylase;HpxO enzyme;FAD-dependent urate oxidase;urate hydroxylase
# substrates: urate [CPD:C00366];NADH [CPD:C00004];H+ [CPD:C00080];O2 [CPD:C00007]
# products: 5-hydroxyisourate [CPD:C11821];NAD+ [CPD:C00003];H2O [CPD:C00001]
#
#
# Flavoenzyme name: FMN reductase [NAD(P)H];FRG
# substrates: FMNH2 [CPD:C01847];NAD+ [CPD:C00003];NADP+ [CPD:C00006]
# products: FMN [CPD:C00061];NADH [CPD:C00004];NADPH [CPD:C00005];H+ [CPD:C00080]
#
#
# Flavoenzyme name: 7,8-didemethyl-8-hydroxy-5-deazariboflavin synthase;FO synthase;fbiC (gene name) (ambiguous);cofG (gene name)
# substrates: 5-amino-5-(4-hydroxybenzyl)-6-(D-ribitylimino)-5,6-dihydrouracil [CPD:C21971];S-adenosyl-L-methionine [CPD:C00019]
# products: 7,8-didemethyl-8-hydroxy-5-deazariboflavin [CPD:C19154];NH3 [CPD:C00014];L-methionine [CPD:C00073];5'-deoxyadenosine [CPD:C05198]
#
#
# Flavoenzyme name: acyl-CoA (8-3)-desaturase;FADS1 (gene name);acyl-CoA 5-desaturase (methylene-interrupted)
# substrates: (8Z,11Z,14Z)-icosa-8,11,14-trienoyl-CoA [CPD:C03595];ferrocytochrome b5 [CPD:C00999];O2 [CPD:C00007];H+ [CPD:C00080];(8Z,11Z,14Z,17Z)-icosa-8,11,14,17-tetraenoyl-CoA [CPD:C16164]
# products: arachidonoyl-CoA [CPD:C02249];ferricytochrome b5 [CPD:C00996];H2O [CPD:C00001];(5Z,8Z,11Z,14Z,17Z)-icosa-5,8,11,14,17-pentaenoyl-CoA [CPD:C16165]
#
#
# Flavoenzyme name: FAD reductase (NADH);NADH-FAD reductase;NADH-dependent FAD reductase;NADH:FAD oxidoreductase;NADH:flavin adenine dinucleotide oxidoreductase
# substrates: FADH2 [CPD:C01352];NAD+ [CPD:C00003]
# products: FAD [CPD:C00016];NADH [CPD:C00004];H+ [CPD:C00080]
#
#
# Flavoenzyme name: 4-hydroxyphenylalkanoate adenylyltransferase FadD29;fadD29 (gene name);4-hydroxyphenylalkanoate adenylase
# substrates: ATP [CPD:C00002];17-(4-hydroxyphenyl)heptadecanoate [CPD:C21446];holo-[(phenol)carboxyphthiodiolenone synthase];17-(4-hydroxyphenyl)heptadecanoyl-adenylate;19-(4-hydroxyphenyl)nonadecanoate [CPD:C21448];19-(4-hydroxyphenyl)nonadecanoyl-adenylate
# products: AMP [CPD:C00020];diphosphate [CPD:C00013];17-(4-hydroxyphenyl)heptadecanoyl-[(phenol)carboxyphthiodiolenone synthase];17-(4-hydroxyphenyl)heptadecanoyl-adenylate;19-(4-hydroxyphenyl)nonadecanoyl-[(phenol)carboxyphthiodiolenone synthase];19-(4-hydroxyphenyl)nonadecanoyl-adenylate
#
#
# Flavoenzyme name: coenzyme F420 hydrogenase;8-hydroxy-5-deazaflavin-reducing hydrogenase;F420-reducing hydrogenase;coenzyme F420-dependent hydrogenase
# substrates: H2 [CPD:C00282];oxidized coenzyme F420 [CPD:C00876]
# products: reduced coenzyme F420 [CPD:C01080]
#
#
# Flavoenzyme name: aerobic 5,6-dimethylbenzimidazole synthase;BluB;flavin destructase
# substrates: FMNH2 [CPD:C01847];O2 [CPD:C00007]
# products: 5,6-dimethylbenzimidazole [CPD:C03114];D-erythrose 4-phosphate [CPD:C00279];other product(s)
#
#
# Flavoenzyme name: FMN hydrolase;FMN phosphatase;AtcpFHy1
# substrates: FMN [CPD:C00061];H2O [CPD:C00001]
# products: riboflavin [CPD:C00255];phosphate [CPD:C00009]
#
#
# Flavoenzyme name: FAD-AMP lyase (cyclizing);FMN cyclase;FAD AMP-lyase (cyclic-FMN-forming)
# substrates: FAD [CPD:C00016]
# products: AMP [CPD:C00020];riboflavin cyclic-4',5'-phosphate [CPD:C16071]
#
#
# Flavoenzyme name: CTP-dependent riboflavin kinase;Methanocaldococcus jannaschii Mj0056;Mj0056
# substrates: CTP [CPD:C00063];riboflavin [CPD:C00255]
# products: CDP [CPD:C00112];FMN [CPD:C00061]
#
#
# Flavoenzyme name: acyl-CoA 6-desaturase;Delta6-desaturase;Delta6-fatty acyl-CoA desaturase;Delta6-acyl CoA desaturase;fatty acid Delta6-desaturase;fatty acid 6-desaturase;linoleate desaturase;linoleic desaturase;linoleic acid desaturase;linoleoyl CoA desaturase;linoleoyl-coenzyme A desaturase;long-chain fatty acid Delta6-desaturase;linoleoyl-CoA,hydrogen-donor:oxygen oxidoreductase;linoleoyl-CoA desaturase;FADS2 (gene name)
# substrates: linoleoyl-CoA [CPD:C02050];ferrocytochrome b5 [CPD:C00999];O2 [CPD:C00007];H+ [CPD:C00080];alpha-linolenoyl-CoA [CPD:C16162]
# products: gamma-linolenoyl-CoA [CPD:C03035];ferricytochrome b5 [CPD:C00996];H2O [CPD:C00001];stearidonoyl-CoA [CPD:C16163]
#
#
# Flavoenzyme name: 8-hydroxy-5-deazaflavin:NADPH oxidoreductase;8-OH-5dFl:NADPH oxidoreductase
# substrates: reduced coenzyme F420 [CPD:C01080];NADP+ [CPD:C00006]
# products: oxidized coenzyme F420 [CPD:C00876];NADPH [CPD:C00005];H+ [CPD:C00080]
#
#
# Flavoenzyme name: phenol 2-monooxygenase (FADH2);pheA1 (gene name)
# substrates: phenol [CPD:C00146];FADH2 [CPD:C01352];O2 [CPD:C00007]
# products: catechol [CPD:C00090];FAD [CPD:C00016];H2O [CPD:C00001]
#
#
# Flavoenzyme name: toxoflavin synthase;toxA (gene name)
# substrates: S-adenosyl-L-methionine [CPD:C00019];1,6-didemethyltoxoflavin [CPD:C21956];reumycin [CPD:C21957]
# products: S-adenosyl-L-homocysteine [CPD:C00021];reumycin [CPD:C21957];toxoflavine [CPD:C16789]
#
#
# Flavoenzyme name: long-chain fatty acid adenylyltransferase FadD28;fadD28 (gene name)
# substrates: ATP [CPD:C00002];long-chain fatty acid [CPD:C00638];holo-[mycocerosate synthase];long-chain acyl-adenylate ester
# products: AMP [CPD:C00020];diphosphate [CPD:C00013];long-chain acyl-[mycocerosate synthase];long-chain acyl-adenylate ester
#
#
# Flavoenzyme name: flavin reductase (NADPH);NADPH:flavin oxidoreductase;riboflavin mononucleotide (reduced nicotinamide adenine dinucleotide phosphate) reductase;flavin mononucleotide reductase;flavine mononucleotide reductase;FMN reductase (NADPH);NADPH-dependent FMN reductase;NADPH-flavin reductase;NADPH-FMN reductase;NADPH-specific FMN reductase;riboflavin mononucleotide reductase;riboflavine mononucleotide reductase;NADPH2 dehydrogenase (flavin);NADPH2:riboflavin oxidoreductase
# substrates: reduced riboflavin [CPD:C01007];NADP+ [CPD:C00006]
# products: riboflavin [CPD:C00255];NADPH [CPD:C00005];H+ [CPD:C00080]
#
#
# Flavoenzyme name: 8-demethyl-8-aminoriboflavin-5'-phosphate synthase;rosB (gene name)
# substrates: L-glutamate [CPD:C00025];FMN [CPD:C00061];O2 [CPD:C00007];H2O [CPD:C00001];acceptor [CPD:C00028];8-demethyl-8-formylriboflavin 5'-phosphate [CPD:C21803];8-carboxy-8-demethylriboflavin 5'-phosphate [CPD:C21804]
# products: 2-oxoglutarate [CPD:C00026];8-amino-8-demethylriboflavin 5'-phosphate [CPD:C21805];CO2 [CPD:C00011];reduced acceptor [CPD:C00030];8-demethyl-8-formylriboflavin 5'-phosphate [CPD:C21803];H2O [CPD:C00001];8-carboxy-8-demethylriboflavin 5'-phosphate [CPD:C21804]
#
#
# Flavoenzyme name: (R)-pantolactone dehydrogenase (flavin);2-dehydropantolactone reductase (flavin);2-dehydropantoyl-lactone reductase (flavin);(R)-pantoyllactone dehydrogenase (flavin)
# substrates: (R)-pantolactone [CPD:C01012];acceptor [CPD:C00028]
# products: 2-dehydropantolactone [CPD:C01125];reduced acceptor [CPD:C00030]
#
#
# Flavoenzyme name: acyl-lipid (n+3)-(Z)-desaturase (ferredoxin);acyl-lipid omega6-desaturase (ferredoxin);oleate desaturase (ambiguous);linoleate synthase (ambiguous);oleoyl-CoA desaturase (ambiguous);oleoylphosphatidylcholine desaturase (ambiguous);phosphatidylcholine desaturase (ambiguous);FAD6 (gene name)
# substrates: oleoyl-[glycerolipid];reduced ferredoxin [iron-sulfur] cluster [CPD:C00138];O2 [CPD:C00007];H+ [CPD:C00080]
# products: linoleoyl-[glycerolipid] [CPD:C21529];oxidized ferredoxin [iron-sulfur] cluster [CPD:C00139];H2O [CPD:C00001]
#
#
# Flavoenzyme name: flavin-containing monooxygenase;dimethylaniline oxidase;dimethylaniline N-oxidase;FAD-containing monooxygenase;N,N-dimethylaniline monooxygenase;DMA oxidase;flavin mixed function oxidase;Ziegler's enzyme;mixed-function amine oxidase;FMO;FMO-I;FMO-II;FMO1;FMO2;FMO3;FMO4;FMO5;flavin monooxygenase;methylphenyltetrahydropyridine N-monooxygenase;1-methyl-4-phenyl-1,2,3,6-tetrahydropyridine:oxygen N-oxidoreductase;dimethylaniline monooxygenase (N-oxide-forming)
# substrates: N,N-dimethylaniline [CPD:C02846];NADPH [CPD:C00005];H+ [CPD:C00080];O2 [CPD:C00007]
# products: N,N-dimethylaniline N-oxide [CPD:C01183];NADP+ [CPD:C00006];H2O [CPD:C00001]
#
#
# Flavoenzyme name: NADPH---hemoprotein reductase;CPR;FAD-cytochrome c reductase;NADP-cytochrome c reductase;NADP-cytochrome reductase;NADPH-dependent cytochrome c reductase;NADPH:P-450 reductase;NADPH:ferrihemoprotein oxidoreductase;NADPH---cytochrome P-450 oxidoreductase;NADPH-cytochrome c oxidoreductase;NADPH-cytochrome c reductase;NADPH---cytochrome p-450 reductase;NADPH-ferricytochrome c oxidoreductase;NADPH-ferrihemoprotein reductase;TPNH2 cytochrome c reductase;TPNH-cytochrome c reductase;aldehyde reductase (NADPH-dependent);cytochrome P-450 reductase;cytochrome c reductase (reduced nicotinamide adenine dinucleotide phosphate, NADPH, NADPH-dependent);dihydroxynicotinamide adenine dinucleotide phosphate-cytochrome c reductase;ferrihemoprotein P-450 reductase;reduced nicotinamide adenine dinucleotide phosphate-cytochrome c reductase;reductase, cytochrome c (reduced nicotinamide adenine dinucleotide phosphate)
# substrates: NADPH [CPD:C00005];H+ [CPD:C00080];oxidized hemoprotein
# products: NADP+ [CPD:C00006];reduced hemoprotein
#
#
# Flavoenzyme name: non-specific protein-tyrosine kinase;ABL;ABL1;ABL2;ABLL;ACK1;ACK2;AGMX1;ARG;ATK;ATP:protein-tyrosine O-phosphotransferase (ambiguous);BLK;Bmk;BMX;BRK;Bruton's tyrosine kinase;Bsk;BTK;BTKL;CAKb;Cdgip;CHK;CSK;CTK;CYL;cytoplasmic protein tyrosine kinase;EMT;ETK;Fadk;FAK;FAK2;FER;Fert1/2;FES;FGR;focal adhesion kinase;FPS;FRK;FYN;HCK;HCTK;HYL;IMD1;ITK;IYK;JAK1;JAK2;JAK3;Janus kinase 1;Janus kinase 2;Janus kinase 3;JTK1;JTK9;L-JAK;LCK;LSK;LYN;MATK;Ntk;p60c-src protein tyrosine kinase;PKB;protein-tyrosine kinase (ambiguous);PSCTK;PSCTK1;PSCTK2;PSCTK4;PSCTK5;PTK2;PTK2B;PTK6;PYK2;RAFTK;RAK;Rlk;Sik;SLK;SRC;SRC2;SRK;SRM;SRMS;STD;SYK;SYN;Tck;TEC;TNK1;Tsk;TXK;TYK2;TYK3;YES1;YK2;ZAP70
# substrates: ATP [CPD:C00002];[protein]-L-tyrosine [CPD:C00585]
# products: ADP [CPD:C00008];[protein]-L-tyrosine phosphate [CPD:C01167]
#
#
# Flavoenzyme name: glyceraldehyde dehydrogenase (FAD-containing);glyceraldehyde oxidoreductase
# substrates: D-glyceraldehyde [CPD:C00577];H2O [CPD:C00001];acceptor [CPD:C00028]
# products: D-glycerate [CPD:C00258];reduced acceptor [CPD:C00030]
#
#
# Flavoenzyme name: monoamine oxidase;adrenalin oxidase;adrenaline oxidase;amine oxidase (ambiguous);amine oxidase (flavin-containing);amine:oxygen oxidoreductase (deaminating) (flavin-containing);epinephrine oxidase;MAO;MAO A;MAO B;MAO-A;MAO-B;monoamine oxidase A;monoamine oxidase B;monoamine:O2 oxidoreductase (deaminating);polyamine oxidase (ambiguous);serotonin deaminase;spermidine oxidase (ambiguous);spermine oxidase (ambiguous);tyraminase;tyramine oxidase
# substrates: RCH2NHR' [CPD:C21299];H2O [CPD:C00001];O2 [CPD:C00007]
# products: RCHO [CPD:C00071];R'NH2 [CPD:C21300];H2O2 [CPD:C00027]
#
#
# Flavoenzyme name: 4-hydroxybenzoate adenylyltransferase FadD22;fadD22 (gene name);4-hydroxybenzoate adenylase
# substrates: ATP [CPD:C00002];4-hydroxybenzoate [CPD:C00156];holo-[4-hydroxyphenylalkanoate synthase];4-hydroxybenzoyl-adenylate [CPD:C21497]
# products: AMP [CPD:C00020];diphosphate [CPD:C00013];4-hydroxybenzoyl-[4-hydroxyphenylalkanoate synthase];4-hydroxybenzoyl-adenylate [CPD:C21497]
#
#
# Flavoenzyme name: Delta12 acyl-lipid conjugase (11E,13E-forming);fatty acid Delta12-conjugase (ambiguous);FADX (gene name)
# substrates: linoleoyl-[glycerolipid] [CPD:C21529];ferrocytochrome b5 [CPD:C00999];O2 [CPD:C00007];H+ [CPD:C00080];gamma-linolenoyl-[glycerolipid]
# products: alpha-eleostearoyl-[glycerolipid];ferricytochrome b5 [CPD:C00996];H2O [CPD:C00001];alpha-parinaroyl-[glycerolipid]
#
#
# Flavoenzyme name: FMN-dependent NADH-azoreductase;azoR (gene name);NADH-azoreductase
# substrates: anthranilate [CPD:C00108];N,N-dimethyl-1,4-phenylenediamine [CPD:C04203];NAD+ [CPD:C00003]
# products: 2-(4-dimethylaminophenyl)diazenylbenzoate [CPD:C19459];NADH [CPD:C00004];H+ [CPD:C00080]
#
#
# Flavoenzyme name: bacterial luciferase;aldehyde monooxygenase;luciferase;Vibrio fischeri luciferase;alkanal,reduced-FMN:oxygen oxidoreductase (1-hydroxylating, luminescing);alkanal,FMNH2:oxygen oxidoreductase (1-hydroxylating, luminescing);alkanal monooxygenase (FMN);aldehyde,FMNH2:oxygen oxidoreductase (1-hydroxylating, luminescing)
# substrates: long-chain aldehyde [CPD:C00609];FMNH2 [CPD:C01847];O2 [CPD:C00007]
# products: long-chain fatty acid [CPD:C00638];FMN [CPD:C00061];H2O [CPD:C00001];hnu [CPD:C00205]
#
#
# Flavoenzyme name: L-lactate dehydrogenase (cytochrome);lactic acid dehydrogenase;cytochrome b2 (flavin-free derivative of flavocytochrome b2);flavocytochrome b2;L-lactate cytochrome c reductase;L(+)-lactate:cytochrome c oxidoreductase;dehydrogenase, lactate (cytochrome);L-lactate cytochrome c oxidoreductase;lactate dehydrogenase (cytochrome);lactic cytochrome c reductase
# substrates: (S)-lactate [CPD:C00186];ferricytochrome c [CPD:C00125]
# products: pyruvate [CPD:C00022];ferrocytochrome c [CPD:C00126];H+ [CPD:C00080]
#
#
# Flavoenzyme name: albendazole monooxygenase;albendazole oxidase (misleading);albendazole sulfoxidase (ambiguous);FMO3 (gene name);albendazole monooxygenase (flavin-containing)
# substrates: albendazole [CPD:C01779];NADPH [CPD:C00005];H+ [CPD:C00080];O2 [CPD:C00007]
# products: albendazole S-oxide [CPD:C02809];NADP+ [CPD:C00006];H2O [CPD:C00001]
#
#
# Flavoenzyme name: 3-[(3aS,4S,7aS)-7a-methyl-1,5-dioxo-octahydro-1H-inden-4-yl]propanoate---CoA ligase;fadD3 (gene name);HIP---CoA ligase
# substrates: ATP [CPD:C00002];3-[(3aS,4S,7aS)-7a-methyl-1,5-dioxo-octahydro-1H-inden-4-yl]propanoate [CPD:C20199];CoA [CPD:C00010]
# products: AMP [CPD:C00020];diphosphate [CPD:C00013];3-[(3aS,4S,7aS)-7a-methyl-1,5-dioxo-octahydro-1H-inden-4-yl]propanoyl-CoA [CPD:C20838]
#
#
# Flavoenzyme name: trimethylamine monooxygenase;flavin-containing monooxygenase 3;FMO3;tmm (gene name)
# substrates: N,N,N-trimethylamine;NADPH [CPD:C00005];H+ [CPD:C00080];O2 [CPD:C00007]
# products: N,N,N-trimethylamine N-oxide;NADP+ [CPD:C00006];H2O [CPD:C00001]
#
#
# Flavoenzyme name: anthranilate 3-monooxygenase (FAD);anthranilate 3-hydroxylase;anthranilate hydroxylase
# substrates: anthranilate [CPD:C00108];FADH2 [CPD:C01352];O2 [CPD:C00007]
# products: 3-hydroxyanthranilate [CPD:C00632];FAD [CPD:C00016];H2O [CPD:C00001]
#
#
# Flavoenzyme name: acyl-lipid omega-6 desaturase (cytochrome b5);oleate desaturase (ambiguous);linoleate synthase (ambiguous);oleoyl-CoA desaturase (incorrect);oleoylphosphatidylcholine desaturase (ambiguous);phosphatidylcholine desaturase (ambiguous);n-6 desaturase (ambiguous);FAD2 (gene name)
# substrates: oleoyl-[glycerolipid];ferrocytochrome b5 [CPD:C00999];O2 [CPD:C00007];H+ [CPD:C00080]
# products: linoleoyl-[glycerolipid] [CPD:C21529];ferricytochrome b5 [CPD:C00996];H2O [CPD:C00001]
#
#
# Flavoenzyme name: acyl-lipid (9+3)-(E)-desaturase;acyl-lipid 12-(E)-desaturase;DsFAD2-1;FADX
# substrates: oleoyl-[glycerolipid];ferrocytochrome b5 [CPD:C00999];O2 [CPD:C00007];H+ [CPD:C00080];palmitoleoyl-[glycerolipid]
# products: (9Z,12E)-octadeca-9,12-dienoyl-[glycerolipid];ferricytochrome b5 [CPD:C00996];H2O [CPD:C00001];(9Z,12E)-hexadeca-9,12-dienoyl-[glycerolipid]
#
#
# Flavoenzyme name: acyl-lipid (8-3)-desaturase;acyl-lipid 5-desaturase;Delta5-fatty-acid desaturase;DES5 (gene name);D5des (gene name);FADS1
# substrates: (8Z,11Z,14Z)-icosa-8,11,14-trienoyl-[glycerolipid];ferrocytochrome b5 [CPD:C00999];O2 [CPD:C00007];H+ [CPD:C00080];(8Z,11Z,14Z,17Z)-icosa-8,11,14,17-tetraenoyl-[glycerolipid]
# products: (5Z,8Z,11Z,14Z)-icosatetra-5,8,11,14-tetraenoyl-[glycerolipid];ferricytochrome b5 [CPD:C00996];H2O [CPD:C00001];(5Z,8Z,11Z,14Z,17Z)-icosa-5,8,11,14,17-pentaenoyl-[glycerolipid]
#
#
# Flavoenzyme name: FAD synthetase;FAD pyrophosphorylase;riboflavin mononucleotide adenylyltransferase;adenosine triphosphate-riboflavin mononucleotide transadenylase;adenosine triphosphate-riboflavine mononucleotide transadenylase;riboflavin adenine dinucleotide pyrophosphorylase;riboflavine adenine dinucleotide adenylyltransferase;flavin adenine dinucleotide synthetase;FADS;FMN adenylyltransferase
# substrates: ATP [CPD:C00002];FMN [CPD:C00061]
# products: diphosphate [CPD:C00013];FAD [CPD:C00016]
#
#
# Flavoenzyme name: aldehyde dehydrogenase (FAD-independent);aldehyde oxidase;aldehyde oxidoreductase;Mop;AORDd
# substrates: aldehyde [CPD:C00071];H2O [CPD:C00001];acceptor [CPD:C00028]
# products: carboxylate [CPD:C00060];reduced acceptor [CPD:C00030]
#
#
# Flavoenzyme name: riboflavin synthase;heavy riboflavin synthase;light riboflavin synthase;riboflavin synthetase;riboflavine synthase;riboflavine synthetase
# substrates: 6,7-dimethyl-8-(1-D-ribityl)lumazine
# products: riboflavin [CPD:C00255];4-(1-D-ribitylamino)-5-amino-2,6-dihydroxypyrimidine [CPD:C04732]
#
#
# Flavoenzyme name: methanesulfonate monooxygenase (FMNH2);msuD (gene name);ssuD (gene name)
# substrates: methanesulfonate [CPD:C11145];FMNH2 [CPD:C01847];O2 [CPD:C00007]
# products: formaldehyde [CPD:C00067];FMN [CPD:C00061];sulfite [CPD:C00094];H2O [CPD:C00001]
#
#
# Flavoenzyme name: 4,4'-diapophytoene desaturase (4,4'-diapolycopene-forming);dehydrosqualene desaturase (ambiguous);CrtN (ambiguous);4,4'-diapophytoene:FAD oxidoreductase (ambiguous);15-cis-4,4'-diapophytoene:FAD oxidoreductase;4,4'-diapophytoene desaturase (ambiguous)
# substrates: 15-cis-4,4'-diapophytoene [CPD:C16144];FAD [CPD:C00016];all-trans-4,4'-diapophytofluene;all-trans-4,4'-diapo-zeta-carotene;all-trans-4,4'-diaponeurosporene
# products: all-trans-4,4'-diapolycopene;FADH2 [CPD:C01352];all-trans-4,4'-diapophytofluene;all-trans-4,4'-diapo-zeta-carotene;all-trans-4,4'-diaponeurosporene
#
#
# Flavoenzyme name: flavin reductase (NADH);NADH-dependent flavin reductase;flavin:NADH oxidoreductase
# substrates: reduced flavin [CPD:C19790];NAD+ [CPD:C00003]
# products: flavin [CPD:C00176];NADH [CPD:C00004];H+ [CPD:C00080]
#
#
# Flavoenzyme name: FMN reductase (NADPH);FRP;flavin reductase P;SsuE
# substrates: FMNH2 [CPD:C01847];NADP+ [CPD:C00006]
# products: FMN [CPD:C00061];NADPH [CPD:C00005];H+ [CPD:C00080]
#
#
# Flavoenzyme name: palmitoyl-[glycerolipid] 7-desaturase;FAD5
# substrates: 1-acyl-2-palmitoyl-[glycerolipid];reduced ferredoxin [iron-sulfur] cluster [CPD:C00138];O2 [CPD:C00007];H+ [CPD:C00080]
# products: 1-acyl-2-[(7Z)-hexadec-7-enoyl]-[glycerolipid];oxidized ferredoxin [iron-sulfur] cluster [CPD:C00139];H2O [CPD:C00001]
#
#
# Flavoenzyme name: riboflavinase
# substrates: riboflavin [CPD:C00255];H2O [CPD:C00001]
# products: ribitol [CPD:C00474];lumichrome [CPD:C01727]
#
#
# Flavoenzyme name: acyl-lipid omega-3 desaturase (cytochrome b5);FAD3
# substrates: linoleoyl-[glycerolipid] [CPD:C21529];ferrocytochrome b5 [CPD:C00999];O2 [CPD:C00007];H+ [CPD:C00080]
# products: alpha-linolenoyl-[glycerolipid] [CPD:C21531];ferricytochrome b5 [CPD:C00996];H2O [CPD:C00001]
#
#
# Flavoenzyme name: 4-hydroxyphenylacetate 3-monooxygenase;p-hydroxyphenylacetate 3-hydroxylase;4-hydroxyphenylacetic acid-3-hydroxylase;p-hydroxyphenylacetate hydroxylase (FAD);4 HPA 3-hydroxylase;p-hydroxyphenylacetate 3-hydroxylase (FAD);HpaB
# substrates: 4-hydroxyphenylacetate [CPD:C00642];FADH2 [CPD:C01352];O2 [CPD:C00007]
# products: 3,4-dihydroxyphenylacetate [CPD:C01161];FAD [CPD:C00016];H2O [CPD:C00001]
#
#
# Flavoenzyme name: FAD reductase [NAD(P)H];GTNG_3158 (gene name)
# substrates: FADH2 [CPD:C01352];NAD+ [CPD:C00003];NADP+ [CPD:C00006]
# products: FAD [CPD:C00016];NADH [CPD:C00004];NADPH [CPD:C00005];H+ [CPD:C00080]
#
#
# Flavoenzyme name: long-chain fatty acid adenylase/transferase FadD26;FadD26
# substrates: ATP [CPD:C00002];long-chain fatty acid [CPD:C00638];holo-[(phenol)carboxyphthiodiolenone synthase];long-chain fatty-acyl adenylate ester
# products: AMP [CPD:C00020];diphosphate [CPD:C00013];long-chain acyl-[(phenol)carboxyphthiodiolenone synthase];long-chain fatty-acyl adenylate ester
#
#
# Flavoenzyme name: dichloroarcyriaflavin A synthase
# substrates: dichlorochromopyrrolate [CPD:C19698];O2 [CPD:C00007];NADH [CPD:C00004];H+ [CPD:C00080]
# products: dichloroarcyriaflavin A [CPD:C19699];CO2 [CPD:C00011];H2O [CPD:C00001];NAD+ [CPD:C00003]
#
#
# Flavoenzyme name: acyl-lipid (7-3)-desaturase;D4Des (gene name);des1 (gene name);CrDelta4FAD (gene name);acyl-lipid 4-desaturase
# substrates: (7Z,10Z,13Z,16Z,19Z)-docosa-7,10,13,16,19-pentaenoyl-[glycerolipid];ferrocytochrome b5 [CPD:C00999];O2 [CPD:C00007];H+ [CPD:C00080];(7Z,10Z,13Z,16Z)-docosa-7,10,13,16-tetraenoyl-[glycerolipid]
# products: (4Z,7Z,10Z,13Z,16Z,19Z)-docosa-4,7,10,13,16,19-hexaenoyl-[glycerolipid];ferricytochrome b5 [CPD:C00996];H2O [CPD:C00001];(4Z,7Z,10Z,13Z,16Z)-docosa-4,7,10,13,16-pentaenoyl-[glycerolipid]
#
#
# Flavoenzyme name: glycerol-3-phosphate dehydrogenase;alpha-glycerophosphate dehydrogenase;alpha-glycerophosphate dehydrogenase (acceptor);anaerobic glycerol-3-phosphate dehydrogenase;DL-glycerol 3-phosphate oxidase (misleading);FAD-dependent glycerol-3-phosphate dehydrogenase;FAD-dependent sn-glycerol-3-phosphate dehydrogenase;FAD-GPDH;FAD-linked glycerol 3-phosphate dehydrogenase;FAD-linked L-glycerol-3-phosphate dehydrogenase;flavin-linked glycerol-3-phosphate dehydrogenase;flavoprotein-linked L-glycerol 3-phosphate dehydrogenase;glycerol 3-phosphate cytochrome c reductase (misleading);glycerol phosphate dehydrogenase;glycerol phosphate dehydrogenase (acceptor);glycerol phosphate dehydrogenase (FAD);glycerol-3-phosphate CoQ reductase;glycerol-3-phosphate dehydrogenase (flavin-linked);glycerol-3-phosphate:CoQ reductase;glycerophosphate dehydrogenase;L-3-glycerophosphate-ubiquinone oxidoreductase;L-glycerol-3-phosphate dehydrogenase (ambiguous);L-glycerophosphate dehydrogenase;mGPD;mitochondrial glycerol phosphate dehydrogenase;NAD+-independent glycerol phosphate dehydrogenase;pyridine nucleotide-independent L-glycerol 3-phosphate dehydrogenase;sn-glycerol 3-phosphate oxidase (misleading);sn-glycerol-3-phosphate dehydrogenase;sn-glycerol-3-phosphate:(acceptor) 2-oxidoreductase;sn-glycerol-3-phosphate:acceptor 2-oxidoreductase
# substrates: sn-glycerol 3-phosphate [CPD:C00093];quinone [CPD:C15602]
# products: glycerone phosphate [CPD:C00111];quinol [CPD:C15603]
#
#
# Flavoenzyme name: 8-amino-8-demethylriboflavin N,N-dimethyltransferase;rosA (gene name)
# substrates: S-adenosyl-L-methionine [CPD:C00019];8-amino-8-demethylriboflavin [CPD:C21646];8-demethyl-8-(methylamino)riboflavin [CPD:C21648]
# products: S-adenosyl-L-homocysteine [CPD:C00021];roseoflavin [CPD:C21647];8-demethyl-8-(methylamino)riboflavin [CPD:C21648]
#
#
# Flavoenzyme name: palmitoyl-[glycerolipid] 3-(E)-desaturase;FAD4
# substrates: 1-acyl-2-palmitoyl-[glycerolipid];reduced ferredoxin [iron-sulfur] cluster [CPD:C00138];O2 [CPD:C00007];H+ [CPD:C00080]
# products: 1-acyl-2-[(3E)-hexadec-3-enoyl]-[glycerolipid];oxidized ferredoxin [iron-sulfur] cluster [CPD:C00139];H2O [CPD:C00001]
#
#
# Flavoenzyme name: 3-oxocholest-4-en-26-oate---CoA ligase;fadD19 (gene name)
# substrates: ATP [CPD:C00002];(25S)-3-oxocholest-4-en-26-oate [CPD:C21076];CoA [CPD:C00010]
# products: AMP [CPD:C00020];diphosphate [CPD:C00013];(25S)-3-oxocholest-4-en-26-oyl-CoA [CPD:C20840]
#
#
# Flavoenzyme name: [histone H3]-N6,N6-dimethyl-L-lysine4 FAD-dependent demethylase;KDM1 (gene name);LSD1 (gene name);lysine-specific histone demethylase 1
# substrates: [histone H3]-N6,N6-dimethyl-L-lysine4;acceptor [CPD:C00028];H2O [CPD:C00001];[histone H3]-N6-methyl-L-lysine4
# products: [histone H3]-L-lysine4;formaldehyde [CPD:C00067];reduced acceptor [CPD:C00030];[histone H3]-N6-methyl-L-lysine4
#
#
# Flavoenzyme name: malate dehydrogenase (quinone);FAD-dependent malate-vitamin K reductase;malate-vitamin K reductase;(S)-malate:(acceptor) oxidoreductase;L-malate-quinone oxidoreductase;malate:quinone oxidoreductase;malate quinone oxidoreductase;MQO;malate:quinone reductase;malate dehydrogenase (acceptor);FAD-dependent malate dehydrogenase
# substrates: (S)-malate [CPD:C00149];quinone [CPD:C15602]
# products: oxaloacetate [CPD:C00036];reduced quinone [CPD:C15603]
#
#
# Flavoenzyme name: glucose 1-dehydrogenase (FAD, quinone);glucose dehydrogenase (Aspergillus);FAD-dependent glucose dehydrogenase;D-glucose:(acceptor) 1-oxidoreductase;glucose dehydrogenase (acceptor);gdh (gene name)
# substrates: D-glucose [CPD:C00031];quinone [CPD:C15602]
# products: D-glucono-1,5-lactone [CPD:C00198];quinol [CPD:C15603]
#
#
# Flavoenzyme name: long-chain fatty acid adenylase/transferase FadD23;fadD23 (gene name);long-chain fatty acid adenylyltransferase FadD23
# substrates: ATP [CPD:C00002];stearate [CPD:C01530];holo-[(hydroxy)phthioceranic acid synthase] [CPD:C22133];(stearoyl)adenylate [CPD:C22132];palmitate [CPD:C00249];(palmitoyl)adenylate [CPD:C22135]
# products: AMP [CPD:C00020];diphosphate [CPD:C00013];stearoyl-[(hydroxy)phthioceranic acid synthase] [CPD:C22134];(stearoyl)adenylate [CPD:C22132];palmitoyl-[(hydroxy)phthioceranic acid synthase] [CPD:C22124];(palmitoyl)adenylate [CPD:C22135]
#
#
# Flavoenzyme name: 2-phospho-L-lactate transferase;LPPG:Fo 2-phospho-L-lactate transferase;LPPG:7,8-didemethyl-8-hydroxy-5-deazariboflavin 2-phospho-L-lactate transferase;MJ1256;lactyl-2-diphospho-(5')guanosine:Fo 2-phospho-L-lactate transferase;CofD
# substrates: (2S)-lactyl-2-diphospho-5'-guanosine [CPD:C19155];7,8-didemethyl-8-hydroxy-5-deazariboflavin [CPD:C19154]
# products: GMP [CPD:C00144];coenzyme F420-0 [CPD:C19153]
#
#
# Flavoenzyme name: FAD:protein FMN transferase;flavin transferase;apbE (gene name)
# substrates: FAD [CPD:C00016];[protein]-L-threonine [CPD:C19803]
# products: [protein]-FMN-L-threonine [CPD:C20730];AMP [CPD:C00020]

# %%
product_set=set()

# %%
for enzyme in enzyme_list:
    product_lst=enzyme.get('PRODUCT', [])
    for product in product_lst:
        product=product.replace(';', '')
        product_set.add(product)

# %%
substrate_set=set()

# %%
for enzyme in enzyme_list:
    substrate_lst=enzyme.get('SUBSTRATE', [])
    for substrate in substrate_lst:
        substrate=substrate.replace(';', '')
        substrate_set.add(substrate)

# %%
def cpd_to_free_energy(cpd_number):
    try:
        free_energy=df[df['!Identifiers:kegg.compound']==cpd_number]['!dG0 (kJ/mol)'].values[0]
        return free_energy
    except:
        return None

# %%
def energy_mapper(substrate, substrate_free_energy):
    return {substrate:substrate_free_energy}

# %%
pattern = '\[CPD:(.+)\]'
for substrate in substrate_set:
    cpd_number = re.findall(pattern, substrate)
    if cpd_number:
        cpd_number=cpd_number[0]
        substrate_free_energy=cpd_to_free_energy(cpd_number)
        substrate_energy_dict= energy_mapper(substrate, substrate_free_energy)
        print(substrate_energy_dict)
# Out:
# {'5-amino-5-(4-hydroxybenzyl)-6-(D-ribitylimino)-5,6-dihydrouracil [CPD:C21971]': None}
# {'D-glucose [CPD:C00031]': -915.9}
# {'19-(4-hydroxyphenyl)nonadecanoate [CPD:C21448]': None}
# {'ATP [CPD:C00002]': -2768.1}
# {'(R)-pantolactone [CPD:C01012]': None}
# {'8-demethyl-8-(methylamino)riboflavin [CPD:C21648]': None}
# {'acceptor [CPD:C00028]': None}
# {'stearate [CPD:C01530]': None}
# {'N,N-dimethyl-1,4-phenylenediamine [CPD:C04203]': None}
# {'[protein]-L-threonine [CPD:C19803]': None}
# {'8-amino-8-demethylriboflavin [CPD:C21646]': None}
# {'riboflavin [CPD:C00255]': None}
# {'3-[(3aS,4S,7aS)-7a-methyl-1,5-dioxo-octahydro-1H-inden-4-yl]propanoate [CPD:C20199]': None}
# {"4'-O-demethylrebeccamycin [CPD:C19700]": None}
# {'alkanesulfonate [CPD:C15521]': None}
# {'alpha-D-glucose 1-phosphate [CPD:C00103]': -1756.9}
# {'O2 [CPD:C00007]': 16.4}
# {'N,N-dimethylaniline [CPD:C02846]': None}
# {'linoleoyl-CoA [CPD:C02050]': None}
# {'dichlorochromopyrrolate [CPD:C19698]': None}
# {'7,8-didemethyl-8-hydroxy-5-deazariboflavin [CPD:C19154]': None}
# {'reduced flavin [CPD:C19790]': None}
# {'S-adenosyl-L-methionine [CPD:C00019]': None}
# {'reduced riboflavin [CPD:C01007]': None}
# {'long-chain aldehyde [CPD:C00609]': None}
# {'H2 [CPD:C00282]': 17.6}
# {'reumycin [CPD:C21957]': None}
# {'reduced ferredoxin [iron-sulfur] cluster [CPD:C00138]': 38.1}
# {'dUMP [CPD:C00365]': None}
# {'aldehyde [CPD:C00071]': None}
# {"RCH2NHR' [CPD:C21299]": None}
# {'L-glutamate [CPD:C00025]': -697.5}
# {"(2S)-lactyl-2-diphospho-5'-guanosine [CPD:C19155]": None}
# {'phenol [CPD:C00146]': None}
# {'5-methyltetrahydrofolate [CPD:C00440]': None}
# {'[protein]-L-tyrosine [CPD:C00585]': None}
# {"15-cis-4,4'-diapophytoene [CPD:C16144]": None}
# {'H2O [CPD:C00001]': -237.2}
# {'(stearoyl)adenylate [CPD:C22132]': None}
# {'long-chain fatty acid [CPD:C00638]': None}
# {'linoleoyl-[glycerolipid] [CPD:C21529]': None}
# {'FADH2 [CPD:C01352]': -38.9}
# {'palmitate [CPD:C00249]': -259.4}
# {'NADH [CPD:C00004]': 22.6}
# {'medium-chain fatty acid [CPD:C21925]': None}
# {'dimethylallyl phosphate [CPD:C21214]': None}
# {'D-glyceraldehyde [CPD:C00577]': -440.0}
# {'anthranilate [CPD:C00108]': None}
# {'5,10-methylenetetrahydrofolate [CPD:C00143]': None}
# {'CoA [CPD:C00010]': 0.0}
# {'methanesulfonate [CPD:C11145]': None}
# {'oxidized coenzyme F420 [CPD:C00876]': None}
# {'FAD [CPD:C00016]': 0.0}
# {'FMNH2 [CPD:C01847]': -38.9}
# {"8-demethyl-8-formylriboflavin 5'-phosphate [CPD:C21803]": None}
# {'ferricytochrome c [CPD:C00125]': 0.0}
# {'albendazole [CPD:C01779]': None}
# {'17-(4-hydroxyphenyl)heptadecanoate [CPD:C21446]': None}
# {'NADP+ [CPD:C00006]': -835.2}
# {'NADPH [CPD:C00005]': -809.2}
# {'(S)-lactate [CPD:C00186]': -516.7}
# {"8-carboxy-8-demethylriboflavin 5'-phosphate [CPD:C21804]": None}
# {'4-hydroxyphenylacetate [CPD:C00642]': None}
# {'CTP [CPD:C00063]': None}
# {'FMN [CPD:C00061]': 0.0}
# {'NAD+ [CPD:C00003]': 0.0}
# {'holo-[(hydroxy)phthioceranic acid synthase] [CPD:C22133]': None}
# {'(8Z,11Z,14Z)-icosa-8,11,14-trienoyl-CoA [CPD:C03595]': None}
# {'reduced coenzyme F420 [CPD:C01080]': None}
# {'H+ [CPD:C00080]': 0.0}
# {'(25S)-3-oxocholest-4-en-26-oate [CPD:C21076]': None}
# {'4-hydroxybenzoate [CPD:C00156]': None}
# {'quinone [CPD:C15602]': None}
# {'resorcinol [CPD:C01751]': None}
# {'alpha-linolenoyl-CoA [CPD:C16162]': None}
# {'(palmitoyl)adenylate [CPD:C22135]': None}
# {'4-hydroxybenzoyl-adenylate [CPD:C21497]': None}
# {'ferrocytochrome b5 [CPD:C00999]': None}
# {'urate [CPD:C00366]': -325.9}
# {'(S)-malate [CPD:C00149]': -842.7}
# {'sn-glycerol 3-phosphate [CPD:C00093]': -1359.0}
# {'(8Z,11Z,14Z,17Z)-icosa-8,11,14,17-tetraenoyl-CoA [CPD:C16164]': None}
# {'1,6-didemethyltoxoflavin [CPD:C21956]': None}

# %%
for product in product_set:
    cpd_number = re.findall(pattern, product)
    if cpd_number:
        cpd_number=cpd_number[0]
        product_free_energy=cpd_to_free_energy(cpd_number)
        product_energy_dict= energy_mapper(product, product_free_energy)
print(product_energy_dict)
# Out:
# {"riboflavin cyclic-4',5'-phosphate [CPD:C16071]": None}
