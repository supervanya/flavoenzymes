# %%
import pandas as pd
from io import StringIO
import requests
import lxml
import importlib
import json

import importlib
import cache
importlib.reload(cache)

from helpers import print_percent_done

# %% [markdown]
# ### TODO still
# - Deduplicate the data within the entities so they are not repeating

# %% [markdown]
# ### Configurables
# Edit the folling options before running the scraper
# - Add the terms to search for on Brenda's website here:
# - Make sure the output and input files are what you want

# %%
useCaching = False # setting this parameter to False will fetch new data from server, instead of using cache
terms = ['FAD','FMN','flavoenzyme','flavin', 'flavoprotein']
import_file = "export/brenda.json"
export_file = "export/brenda_new_export.json" # made the filename different so that old one can not be overriden

# %%
def brenda_request(url):
    headers = {
      "User-Agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.75 Safari/537.36",
      "X-Requested-With": "XMLHttpRequest"
    }
    response = cache.cached_reqest(url, headers=headers, useCaching=useCaching)
    return response

# %%
def search_ligands_brenda(term):
    columns = ['Ligand','EC Number', 'Role', 'Id', 'Structure', 'Discard']
    url = f'https://www.brenda-enzymes.org/result_download.php?a=13&RN=&RNV=1&os=1&pt=&FNV=1&tt=&SYN=&Textmining=&T[0]=2&T[1]=2&V[1]=1&V[2]=2&W[3]={term}&T[3]=2&nolimit=1'
    response = brenda_request(url)
    df = pd.read_csv(StringIO(response), sep='\t', names=columns)
    return df

# %%
def search_enzymes_brenda(term):
    columns = ['EC Number', 'Recommended Name', 'Synonyms', 'Commentary', 'Discard']
    url = f'https://www.brenda-enzymes.org/result_download.php?a=9&RN=&RNV=1&os=1&pt=&FNV=&tt=&SYN=&Textmining=&T[0]=2&T[1]=2&W[2]={term}&T[2]=2&nolimit=1'    
    response = brenda_request(url)
    df = pd.read_csv(StringIO(response), sep='\t', names=columns)
    return df

# %%
def brenda_get_enzyme_data(id):
    link = f'https://www.brenda-enzymes.info/enzyme.php?ecno={id}#NATURAL%20SUBSTRATE'
    response = brenda_request(link)
    return response

# %%
def search_all_terms(terms, search_fn):
    all_dfs = []

    for term in terms:
        df = search_fn(term)
        if (len(df) < 2):
            print(f'[!] skipping search for {term} since nothing was found')
            continue
        else:
            all_dfs.append(df)
    return pd.concat(all_dfs)

# %%
def get_all_ecs(terms):
    
    enzymes_list = set(search_all_terms(terms,search_enzymes_brenda)['EC Number'])
    ligands_list = set(search_all_terms(terms,search_ligands_brenda)['EC Number'])

    ec_set = enzymes_list | ligands_list
    print(f'total ecs found: {len(ec_set)}')

    return ec_set

# %% [markdown]
# # SOAP helper

# %%
import zeep


from zeep import Client
import hashlib

email = 'si485@dispostable.com'
password = 'si485@dispostable'

wsdl = "https://www.brenda-enzymes.org/soap/brenda_zeep.wsdl"
password = hashlib.sha256(password.encode("utf-8")).hexdigest()
client = Client(wsdl)

# %%
poster_child = '1.14.13.2'

# %%
def brendaSOAP(parameters, fn_name):
    fn = client.service[fn_name]
    client.settings.strict = True
    return cache.generic_cached_reqest(request_name=f'brenda_{fn}', params=parameters, request_fn=fn, useCaching=useCaching)

def getSynonyms(ecNumber):
    parameters = (email, password, f"ecNumber*{ecNumber}", 'organism*', 'synonyms*', 'commentary*', 'literature*')
    return brendaSOAP(parameters, 'getSynonyms')

def getReactions(ecNumber):
    parameters = (email, password,f"ecNumber*{ecNumber}", "reaction*", "commentary*", "literature*", "organism*")
    return brendaSOAP(parameters, 'getReaction')

def getSystematicName(ecNumber):
    parameters = (email, password,f"ecNumber*{ecNumber}", "organism*", "systematicName*")
    return brendaSOAP(parameters, 'getSystematicName')

def getSubstrate(ecNumber):
    parameters = (email, password,f"ecNumber*{ecNumber}", "organism*", "substrate*", "reactionPartners*", "ligandStructureId*")
    return brendaSOAP(parameters,'getSubstrate')

def getProduct(ecNumber):
    parameters = (email, password,f"ecNumber*{ecNumber}", "organism*", "product*", "reactionPartners*", "ligandStructureId*")
    return brendaSOAP(parameters,'getProduct')

def getPdb(ecNumber):
    parameters = (email, password,f"ecNumber*{ecNumber}", "organism*", "pdb*")
    return brendaSOAP(parameters,'getPdb')

# %%
all_ecs = get_all_ecs(terms)
# Out:
# found JSON cache
# Getting cached data...
# https://www.brenda-enzymes.org/result_download.php?a=9&RN=&RNV=1&os=1&pt=&FNV=&tt=&SYN=&Textmining=&T[0]=2&T[1]=2&W[2]=FAD&T[2]=2&nolimit=1
# found JSON cache
# Getting cached data...
# https://www.brenda-enzymes.org/result_download.php?a=9&RN=&RNV=1&os=1&pt=&FNV=&tt=&SYN=&Textmining=&T[0]=2&T[1]=2&W[2]=FMN&T[2]=2&nolimit=1
# found JSON cache
# Getting cached data...
# https://www.brenda-enzymes.org/result_download.php?a=9&RN=&RNV=1&os=1&pt=&FNV=&tt=&SYN=&Textmining=&T[0]=2&T[1]=2&W[2]=flavoenzyme&T[2]=2&nolimit=1
# [!] skipping search for flavoenzyme since nothing was found
# found JSON cache
# Getting cached data...
# https://www.brenda-enzymes.org/result_download.php?a=9&RN=&RNV=1&os=1&pt=&FNV=&tt=&SYN=&Textmining=&T[0]=2&T[1]=2&W[2]=flavin&T[2]=2&nolimit=1
# found JSON cache
# Getting cached data...
# https://www.brenda-enzymes.org/result_download.php?a=9&RN=&RNV=1&os=1&pt=&FNV=&tt=&SYN=&Textmining=&T[0]=2&T[1]=2&W[2]=flavoprotein&T[2]=2&nolimit=1
# found JSON cache
# Getting cached data...
# https://www.brenda-enzymes.org/result_download.php?a=13&RN=&RNV=1&os=1&pt=&FNV=1&tt=&SYN=&Textmining=&T[0]=2&T[1]=2&V[1]=1&V[2]=2&W[3]=FAD&T[3]=2&nolimit=1
# found JSON cache
# Getting cached data...
# https://www.brenda-enzymes.org/result_download.php?a=13&RN=&RNV=1&os=1&pt=&FNV=1&tt=&SYN=&Textmining=&T[0]=2&T[1]=2&V[1]=1&V[2]=2&W[3]=FMN&T[3]=2&nolimit=1
# found JSON cache
# Getting cached data...
# https://www.brenda-enzymes.org/result_download.php?a=13&RN=&RNV=1&os=1&pt=&FNV=1&tt=&SYN=&Textmining=&T[0]=2&T[1]=2&V[1]=1&V[2]=2&W[3]=flavoenzyme&T[3]=2&nolimit=1
# [!] skipping search for flavoenzyme since nothing was found
# found JSON cache
# Getting cached data...
# https://www.brenda-enzymes.org/result_download.php?a=13&RN=&RNV=1&os=1&pt=&FNV=1&tt=&SYN=&Textmining=&T[0]=2&T[1]=2&V[1]=1&V[2]=2&W[3]=flavin&T[3]=2&nolimit=1
# found JSON cache
# Getting cached data...
# https://www.brenda-enzymes.org/result_download.php?a=13&RN=&RNV=1&os=1&pt=&FNV=1&tt=&SYN=&Textmining=&T[0]=2&T[1]=2&V[1]=1&V[2]=2&W[3]=flavoprotein&T[3]=2&nolimit=1
# total ecs found: 808

# %% [markdown]
# ### Initializing BrendaDB

# %%
def read_past_data(path=import_file):
    try:
        with open(path) as json_file:
            return json.load(json_file)
    except:
        return {}

# %%
def create_brenda_ec_entry(ec):
    return {
        'SYSNAME': getSystematicName(ec),
        'REACTIONS': getReactions(ec),
        'NAME': getSynonyms(ec),
        'SUBSTRATE': getSubstrate(ec),
        'PRODUCT': getProduct(ec),
        'PDB': getPdb(ec),
        'EC_NUMBER': ec
    }

# %%
client = Client(wsdl)
fn = client.service['getSynonyms']
resp = fn(email, password, "ecNumber*1.1.99.15", 'organism*', 'synonyms*', 'commentary*', 'literature*')


# getSubstrate('1.1.99.15')
resp
# Out:
# []

# %%
fn

# %%
def create_brenda_db(list_of_ecs, previous_db, verbose=False):
    new_db = previous_db
    for index, ec in enumerate(list_of_ecs):
        if ec not in previous_db:
            try:
                entry = create_brenda_ec_entry(ec)
                sysnames = entry['SYSNAME']
                entry_name = sorted(sysnames)[0]['ecNumber']
                new_db[entry_name] = (entry)
                if verbose: 
                    print_percent_done(index=index, length=len(list_of_ecs))
            except:
                print(f"[!] couldn't fetch info for {ec}")
        
    
    # Writing out the results to the file
    with open(export_file, 'w') as outfile:
        json.dump(new_db, outfile)
    print(f'\nSuccessfully written out {len(new_db)} results to "{export_file}"')

    return new_db

# %% [markdown]
# ### Running the Update/Scrape Script

# %%
previous_db = read_past_data(import_file)

# Example of the BrendaDB:
# brenda_enzymes = {
#             ecNumber: {
#                 'SYSNAME': "...", # should this be an array?
#                 'REACTIONS': [{reaction},],
#                 'NAME': ['...',],
#                 'SUBSTRATE': [{substrate},],
#                 'PRODUCT': [{product},],
#                 'PDB': [{pdb}]
#                 'EC_NUMBER': 'ec:1.1.1.1'
#             },
#         }
sorted_ecs = sorted(list(all_ecs))
db = create_brenda_db(sorted_ecs, previous_db, verbose=True)
# Out:
# Getting cached data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75588>?68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7=68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7&ecNumber*1.1.1.205=ecNumber*1.1.1.205&organism*=organism*&si485@dispostable.com=si485@dispostable.com&systematicName*=systematicName*
# Getting cached data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75e80>?68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7=68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7&commentary*=commentary*&ecNumber*1.1.1.205=ecNumber*1.1.1.205&literature*=literature*&organism*=organism*&reaction*=reaction*&si485@dispostable.com=si485@dispostable.com
# Getting cached data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75358>?68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7=68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7&commentary*=commentary*&ecNumber*1.1.1.205=ecNumber*1.1.1.205&literature*=literature*&organism*=organism*&si485@dispostable.com=si485@dispostable.com&synonyms*=synonyms*
# Getting cached data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75dd8>?68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7=68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7&ecNumber*1.1.1.205=ecNumber*1.1.1.205&ligandStructureId*=ligandStructureId*&organism*=organism*&reactionPartners*=reactionPartners*&si485@dispostable.com=si485@dispostable.com&substrate*=substrate*
# Getting cached data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75898>?68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7=68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7&ecNumber*1.1.1.205=ecNumber*1.1.1.205&ligandStructureId*=ligandStructureId*&organism*=organism*&product*=product*&reactionPartners*=reactionPartners*&si485@dispostable.com=si485@dispostable.com
# Getting cached data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f7f588>?68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7=68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7&ecNumber*1.1.1.205=ecNumber*1.1.1.205&organism*=organism*&pdb*=pdb*&si485@dispostable.com=si485@dispostable.com
#
#
# ----> Progress: ░░░░░░░░░ 	1% done
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75588>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.1.99.15", "organism*", "systematicName*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75e80>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.1.99.15", "reaction*", "commentary*", "literature*", "organism*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75358>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.1.99.15", "organism*", "synonyms*", "commentary*", "literature*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75dd8>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.1.99.15", "organism*", "substrate*", "reactionPartners*", "ligandStructureId*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75898>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.1.99.15", "organism*", "product*", "reactionPartners*", "ligandStructureId*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f7f588>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.1.99.15", "organism*", "pdb*"]
# couldn't fetch info for 1.1.99.15
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75588>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.13.11.32", "organism*", "systematicName*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75e80>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.13.11.32", "reaction*", "commentary*", "literature*", "organism*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75358>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.13.11.32", "organism*", "synonyms*", "commentary*", "literature*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75dd8>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.13.11.32", "organism*", "substrate*", "reactionPartners*", "ligandStructureId*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75898>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.13.11.32", "organism*", "product*", "reactionPartners*", "ligandStructureId*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f7f588>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.13.11.32", "organism*", "pdb*"]
# couldn't fetch info for 1.13.11.32
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75588>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.14.12.11", "organism*", "systematicName*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75e80>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.14.12.11", "reaction*", "commentary*", "literature*", "organism*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75358>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.14.12.11", "organism*", "synonyms*", "commentary*", "literature*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75dd8>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.14.12.11", "organism*", "substrate*", "reactionPartners*", "ligandStructureId*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75898>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.14.12.11", "organism*", "product*", "reactionPartners*", "ligandStructureId*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f7f588>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.14.12.11", "organism*", "pdb*"]
#
#
# ----> Progress: █░░░░░░░░ 	15% done
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75588>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.14.13.127", "organism*", "systematicName*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75e80>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.14.13.127", "reaction*", "commentary*", "literature*", "organism*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75358>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.14.13.127", "organism*", "synonyms*", "commentary*", "literature*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75dd8>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.14.13.127", "organism*", "substrate*", "reactionPartners*", "ligandStructureId*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75898>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.14.13.127", "organism*", "product*", "reactionPartners*", "ligandStructureId*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f7f588>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.14.13.127", "organism*", "pdb*"]
#
#
# ----> Progress: █░░░░░░░░ 	18% done
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75588>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.14.15.4", "organism*", "systematicName*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75e80>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.14.15.4", "reaction*", "commentary*", "literature*", "organism*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75358>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.14.15.4", "organism*", "synonyms*", "commentary*", "literature*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75dd8>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.14.15.4", "organism*", "substrate*", "reactionPartners*", "ligandStructureId*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75898>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.14.15.4", "organism*", "product*", "reactionPartners*", "ligandStructureId*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f7f588>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.14.15.4", "organism*", "pdb*"]
#
#
# ----> Progress: ███░░░░░░ 	33% done
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75588>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.14.19.7", "organism*", "systematicName*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75e80>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.14.19.7", "reaction*", "commentary*", "literature*", "organism*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75358>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.14.19.7", "organism*", "synonyms*", "commentary*", "literature*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75dd8>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.14.19.7", "organism*", "substrate*", "reactionPartners*", "ligandStructureId*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75898>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.14.19.7", "organism*", "product*", "reactionPartners*", "ligandStructureId*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f7f588>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.14.19.7", "organism*", "pdb*"]
# couldn't fetch info for 1.14.19.7
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75588>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.14.99.40", "organism*", "systematicName*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75e80>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.14.99.40", "reaction*", "commentary*", "literature*", "organism*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75358>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.14.99.40", "organism*", "synonyms*", "commentary*", "literature*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75dd8>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.14.99.40", "organism*", "substrate*", "reactionPartners*", "ligandStructureId*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75898>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.14.99.40", "organism*", "product*", "reactionPartners*", "ligandStructureId*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f7f588>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.14.99.40", "organism*", "pdb*"]
# couldn't fetch info for 1.14.99.40
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75588>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.14.99.7", "organism*", "systematicName*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75e80>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.14.99.7", "reaction*", "commentary*", "literature*", "organism*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75358>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.14.99.7", "organism*", "synonyms*", "commentary*", "literature*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75dd8>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.14.99.7", "organism*", "substrate*", "reactionPartners*", "ligandStructureId*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75898>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.14.99.7", "organism*", "product*", "reactionPartners*", "ligandStructureId*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f7f588>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.14.99.7", "organism*", "pdb*"]
# couldn't fetch info for 1.14.99.7
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75588>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.17.1.4", "organism*", "systematicName*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75e80>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.17.1.4", "reaction*", "commentary*", "literature*", "organism*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75358>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.17.1.4", "organism*", "synonyms*", "commentary*", "literature*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75dd8>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.17.1.4", "organism*", "substrate*", "reactionPartners*", "ligandStructureId*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75898>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.17.1.4", "organism*", "product*", "reactionPartners*", "ligandStructureId*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f7f588>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.17.1.4", "organism*", "pdb*"]
#
#
# ----> Progress: ████░░░░░ 	41% done
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75588>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.3.3.6", "organism*", "systematicName*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75e80>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.3.3.6", "reaction*", "commentary*", "literature*", "organism*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75358>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.3.3.6", "organism*", "synonyms*", "commentary*", "literature*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75dd8>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.3.3.6", "organism*", "substrate*", "reactionPartners*", "ligandStructureId*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75898>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.3.3.6", "organism*", "product*", "reactionPartners*", "ligandStructureId*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f7f588>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.3.3.6", "organism*", "pdb*"]
#
#
# ----> Progress: █████░░░░ 	52% done
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75588>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.3.99.B12", "organism*", "systematicName*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75e80>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.3.99.B12", "reaction*", "commentary*", "literature*", "organism*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75358>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.3.99.B12", "organism*", "synonyms*", "commentary*", "literature*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75dd8>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.3.99.B12", "organism*", "substrate*", "reactionPartners*", "ligandStructureId*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75898>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.3.99.B12", "organism*", "product*", "reactionPartners*", "ligandStructureId*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f7f588>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.3.99.B12", "organism*", "pdb*"]
# couldn't fetch info for 1.3.99.B12
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75588>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.4.99.B4", "organism*", "systematicName*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75e80>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.4.99.B4", "reaction*", "commentary*", "literature*", "organism*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75358>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.4.99.B4", "organism*", "synonyms*", "commentary*", "literature*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75dd8>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.4.99.B4", "organism*", "substrate*", "reactionPartners*", "ligandStructureId*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75898>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.4.99.B4", "organism*", "product*", "reactionPartners*", "ligandStructureId*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f7f588>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.4.99.B4", "organism*", "pdb*"]
# couldn't fetch info for 1.4.99.B4
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75588>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.5.1.29", "organism*", "systematicName*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75e80>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.5.1.29", "reaction*", "commentary*", "literature*", "organism*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75358>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.5.1.29", "organism*", "synonyms*", "commentary*", "literature*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75dd8>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.5.1.29", "organism*", "substrate*", "reactionPartners*", "ligandStructureId*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75898>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.5.1.29", "organism*", "product*", "reactionPartners*", "ligandStructureId*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f7f588>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.5.1.29", "organism*", "pdb*"]
# couldn't fetch info for 1.5.1.29
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75588>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.6.2.2", "organism*", "systematicName*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75e80>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.6.2.2", "reaction*", "commentary*", "literature*", "organism*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75358>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.6.2.2", "organism*", "synonyms*", "commentary*", "literature*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75dd8>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.6.2.2", "organism*", "substrate*", "reactionPartners*", "ligandStructureId*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75898>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.6.2.2", "organism*", "product*", "reactionPartners*", "ligandStructureId*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f7f588>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.6.2.2", "organism*", "pdb*"]
#
#
# ----> Progress: ██████░░░ 	69% done
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75588>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.6.8.1", "organism*", "systematicName*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75e80>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.6.8.1", "reaction*", "commentary*", "literature*", "organism*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75358>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.6.8.1", "organism*", "synonyms*", "commentary*", "literature*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75dd8>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.6.8.1", "organism*", "substrate*", "reactionPartners*", "ligandStructureId*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75898>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.6.8.1", "organism*", "product*", "reactionPartners*", "ligandStructureId*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f7f588>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.6.8.1", "organism*", "pdb*"]
# couldn't fetch info for 1.6.8.1
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75588>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.6.8.2", "organism*", "systematicName*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75e80>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.6.8.2", "reaction*", "commentary*", "literature*", "organism*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75358>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.6.8.2", "organism*", "synonyms*", "commentary*", "literature*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75dd8>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.6.8.2", "organism*", "substrate*", "reactionPartners*", "ligandStructureId*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75898>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.6.8.2", "organism*", "product*", "reactionPartners*", "ligandStructureId*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f7f588>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.6.8.2", "organism*", "pdb*"]
# couldn't fetch info for 1.6.8.2
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75588>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.7.99.5", "organism*", "systematicName*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75e80>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.7.99.5", "reaction*", "commentary*", "literature*", "organism*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75358>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.7.99.5", "organism*", "synonyms*", "commentary*", "literature*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75dd8>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.7.99.5", "organism*", "substrate*", "reactionPartners*", "ligandStructureId*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75898>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.7.99.5", "organism*", "product*", "reactionPartners*", "ligandStructureId*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f7f588>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.7.99.5", "organism*", "pdb*"]
# couldn't fetch info for 1.7.99.5
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75588>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.8.1.B1", "organism*", "systematicName*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75e80>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.8.1.B1", "reaction*", "commentary*", "literature*", "organism*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75358>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.8.1.B1", "organism*", "synonyms*", "commentary*", "literature*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75dd8>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.8.1.B1", "organism*", "substrate*", "reactionPartners*", "ligandStructureId*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75898>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.8.1.B1", "organism*", "product*", "reactionPartners*", "ligandStructureId*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f7f588>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.8.1.B1", "organism*", "pdb*"]
# couldn't fetch info for 1.8.1.B1
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75588>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.8.99.B1", "organism*", "systematicName*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75e80>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.8.99.B1", "reaction*", "commentary*", "literature*", "organism*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75358>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.8.99.B1", "organism*", "synonyms*", "commentary*", "literature*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75dd8>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.8.99.B1", "organism*", "substrate*", "reactionPartners*", "ligandStructureId*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75898>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.8.99.B1", "organism*", "product*", "reactionPartners*", "ligandStructureId*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f7f588>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*1.8.99.B1", "organism*", "pdb*"]
# couldn't fetch info for 1.8.99.B1
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75588>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*2.5.1.77", "organism*", "systematicName*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75e80>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*2.5.1.77", "reaction*", "commentary*", "literature*", "organism*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75358>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*2.5.1.77", "organism*", "synonyms*", "commentary*", "literature*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75dd8>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*2.5.1.77", "organism*", "substrate*", "reactionPartners*", "ligandStructureId*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75898>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*2.5.1.77", "organism*", "product*", "reactionPartners*", "ligandStructureId*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f7f588>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*2.5.1.77", "organism*", "pdb*"]
# couldn't fetch info for 2.5.1.77
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75588>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*2.7.7.95", "organism*", "systematicName*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75e80>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*2.7.7.95", "reaction*", "commentary*", "literature*", "organism*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75358>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*2.7.7.95", "organism*", "synonyms*", "commentary*", "literature*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75dd8>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*2.7.7.95", "organism*", "substrate*", "reactionPartners*", "ligandStructureId*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75898>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*2.7.7.95", "organism*", "product*", "reactionPartners*", "ligandStructureId*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f7f588>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*2.7.7.95", "organism*", "pdb*"]
# couldn't fetch info for 2.7.7.95
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75588>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*3.4.16.4", "organism*", "systematicName*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75e80>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*3.4.16.4", "reaction*", "commentary*", "literature*", "organism*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75358>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*3.4.16.4", "organism*", "synonyms*", "commentary*", "literature*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75dd8>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*3.4.16.4", "organism*", "substrate*", "reactionPartners*", "ligandStructureId*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75898>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*3.4.16.4", "organism*", "product*", "reactionPartners*", "ligandStructureId*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f7f588>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*3.4.16.4", "organism*", "pdb*"]
# couldn't fetch info for 3.4.16.4
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75588>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*3.4.21.1", "organism*", "systematicName*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75e80>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*3.4.21.1", "reaction*", "commentary*", "literature*", "organism*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75358>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*3.4.21.1", "organism*", "synonyms*", "commentary*", "literature*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75dd8>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*3.4.21.1", "organism*", "substrate*", "reactionPartners*", "ligandStructureId*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75898>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*3.4.21.1", "organism*", "product*", "reactionPartners*", "ligandStructureId*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f7f588>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*3.4.21.1", "organism*", "pdb*"]
# couldn't fetch info for 3.4.21.1
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75588>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*3.4.21.109", "organism*", "systematicName*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75e80>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*3.4.21.109", "reaction*", "commentary*", "literature*", "organism*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75358>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*3.4.21.109", "organism*", "synonyms*", "commentary*", "literature*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75dd8>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*3.4.21.109", "organism*", "substrate*", "reactionPartners*", "ligandStructureId*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75898>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*3.4.21.109", "organism*", "product*", "reactionPartners*", "ligandStructureId*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f7f588>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*3.4.21.109", "organism*", "pdb*"]
# couldn't fetch info for 3.4.21.109
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75588>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*3.4.22.3", "organism*", "systematicName*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75e80>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*3.4.22.3", "reaction*", "commentary*", "literature*", "organism*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75358>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*3.4.22.3", "organism*", "synonyms*", "commentary*", "literature*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75dd8>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*3.4.22.3", "organism*", "substrate*", "reactionPartners*", "ligandStructureId*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75898>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*3.4.22.3", "organism*", "product*", "reactionPartners*", "ligandStructureId*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f7f588>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*3.4.22.3", "organism*", "pdb*"]
# couldn't fetch info for 3.4.22.3
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75588>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*3.4.22.56", "organism*", "systematicName*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75e80>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*3.4.22.56", "reaction*", "commentary*", "literature*", "organism*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75358>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*3.4.22.56", "organism*", "synonyms*", "commentary*", "literature*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75dd8>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*3.4.22.56", "organism*", "substrate*", "reactionPartners*", "ligandStructureId*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75898>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*3.4.22.56", "organism*", "product*", "reactionPartners*", "ligandStructureId*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f7f588>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*3.4.22.56", "organism*", "pdb*"]
# couldn't fetch info for 3.4.22.56
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75588>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*3.4.22.61", "organism*", "systematicName*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75e80>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*3.4.22.61", "reaction*", "commentary*", "literature*", "organism*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75358>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*3.4.22.61", "organism*", "synonyms*", "commentary*", "literature*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75dd8>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*3.4.22.61", "organism*", "substrate*", "reactionPartners*", "ligandStructureId*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75898>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*3.4.22.61", "organism*", "product*", "reactionPartners*", "ligandStructureId*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f7f588>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*3.4.22.61", "organism*", "pdb*"]
# couldn't fetch info for 3.4.22.61
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75588>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*3.4.24.15", "organism*", "systematicName*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75e80>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*3.4.24.15", "reaction*", "commentary*", "literature*", "organism*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75358>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*3.4.24.15", "organism*", "synonyms*", "commentary*", "literature*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75dd8>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*3.4.24.15", "organism*", "substrate*", "reactionPartners*", "ligandStructureId*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75898>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*3.4.24.15", "organism*", "product*", "reactionPartners*", "ligandStructureId*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f7f588>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*3.4.24.15", "organism*", "pdb*"]
# couldn't fetch info for 3.4.24.15
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75588>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*3.4.24.59", "organism*", "systematicName*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75e80>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*3.4.24.59", "reaction*", "commentary*", "literature*", "organism*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75358>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*3.4.24.59", "organism*", "synonyms*", "commentary*", "literature*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75dd8>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*3.4.24.59", "organism*", "substrate*", "reactionPartners*", "ligandStructureId*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75898>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*3.4.24.59", "organism*", "product*", "reactionPartners*", "ligandStructureId*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f7f588>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*3.4.24.59", "organism*", "pdb*"]
# couldn't fetch info for 3.4.24.59
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75588>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*3.4.24.69", "organism*", "systematicName*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75e80>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*3.4.24.69", "reaction*", "commentary*", "literature*", "organism*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75358>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*3.4.24.69", "organism*", "synonyms*", "commentary*", "literature*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75dd8>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*3.4.24.69", "organism*", "substrate*", "reactionPartners*", "ligandStructureId*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75898>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*3.4.24.69", "organism*", "product*", "reactionPartners*", "ligandStructureId*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f7f588>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*3.4.24.69", "organism*", "pdb*"]
# couldn't fetch info for 3.4.24.69
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75588>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*7.2.1.1", "organism*", "systematicName*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75e80>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*7.2.1.1", "reaction*", "commentary*", "literature*", "organism*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75358>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*7.2.1.1", "organism*", "synonyms*", "commentary*", "literature*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75dd8>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*7.2.1.1", "organism*", "substrate*", "reactionPartners*", "ligandStructureId*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f75898>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*7.2.1.1", "organism*", "product*", "reactionPartners*", "ligandStructureId*"]
# Making a request for new data...
# brenda_<zeep.proxy.OperationProxy object at 0x133f7f588>, params: ["si485@dispostable.com", "68a8b3ecc5cecaa6b4bf94e0c89ff02d5d77366ca90f1774aae28e37f3b202a7", "ecNumber*7.2.1.1", "organism*", "pdb*"]
#
#
# ----> Progress: █████████ 	99% done
#
# Successfully written out 784 results to "export/brenda_new_export.json"
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-dd416f4536a0> in <module>
#      14 #         }
#      15 sorted_ecs = sorted(list(all_ecs))
# ---> 16 db = create_brenda_db(sorted_ecs, previous_db, verbose=True)
#
# <ipython-input-15-7b74208a9840> in create_brenda_db(list_of_ecs, previous_db, verbose)
#      18     print(f'\nSuccessfully written out {len(previous_db)} results to "{export_file}"')
#      19
# ---> 20     return db
#
# NameError: name 'db' is not defined

# %%
# check if there are ever more then two sysnames
[db[ez_name]['SYSNAME'][0]['ecNumber'] for ez_name in db.keys() if len(db[ez_name]['SYSNAME']) > 1]
# Out:
# []

# %%
# dataframe to easily work with
df = pd.DataFrame(db).T

# %%
df['NAME']['1.1.1.125']
# Out:
# [{'commentary': None,
#   'synonyms': '2-deoxy-D-gluconate 3-dehydrogenase',
#   'literature': [726324],
#   'organism': 'Escherichia coli',
#   'ecNumber': '1.1.1.125'},
#  {'commentary': None,
#   'synonyms': '2-deoxygluconate dehydrogenase',
#   'literature': [0],
#   'organism': None,
#   'ecNumber': '1.1.1.125'},
#  {'commentary': None,
#   'synonyms': '2-deoxygluconic acid dehydrogenase',
#   'literature': [285818],
#   'organism': 'Pseudomonas sp.',
#   'ecNumber': '1.1.1.125'},
#  {'commentary': None,
#   'synonyms': 'KduD',
#   'literature': [726324],
#   'organism': 'Escherichia coli',
#   'ecNumber': '1.1.1.125'}]

# %%
# next(iter(db.keys()))
db.keys()
# Out:
# dict_keys(['1.1.1.1', '1.1.1.125', '1.1.1.181', '1.1.1.184', '1.1.1.189', '1.1.1.193', '1.1.1.215', '1.1.1.216', '1.1.1.217', '1.1.1.229', '1.1.1.27', '1.7.1.2', '1.5.99.12', '1.1.1.25', '1.1.1.267', '1.1.1.28', '1.1.1.284', '1.1.1.289', '1.1.1.306', '1.1.1.328', '1.1.1.35', '1.1.1.404', '1.1.1.47', '1.1.1.94', '1.1.1.B3', '1.1.1.B58', '1.1.2.3', '1.1.2.4', '1.1.3.10', '1.1.3.12', '1.1.3.13', '1.1.3.15', '1.1.3.17', '1.1.3.19', '1.1.3.2', '1.1.3.20', '1.1.3.21', '1.1.3.23', '1.1.3.28', '1.1.3.37', '1.1.3.38', '1.1.3.39', '1.1.3.4', '1.1.3.41', '1.1.3.42', '1.1.3.43', '1.1.3.44', '1.1.3.45', '1.1.3.46', '1.1.3.47', '1.1.3.49', '1.1.3.5', '1.1.3.6', '1.1.3.7', '1.1.3.8', '1.1.3.9', '1.1.5.10', '1.1.5.12', '1.1.5.3', '1.1.5.4', '1.1.5.9', '1.1.98.3', '1.1.98.4', '1.1.99.1', '1.1.99.11', '1.1.99.13', '1.1.99.18', '1.1.99.2', '1.1.99.20', '1.1.99.21', '1.1.99.27', '1.1.99.29', '1.1.99.3', '1.1.99.31', '1.1.99.37', '1.1.99.39', '1.1.99.4', '1.1.99.40', '1.1.99.42', '1.1.99.6', '1.1.99.9', '1.1.99.B1', '1.1.99.B3', '1.1.99.B9', '1.10.3.16', '1.10.3.4', '1.10.3.6', '1.10.5.1', '1.11.1.1', '1.11.1.17', '1.11.1.23', '1.12.1.2', '1.12.1.3', '1.12.1.4', '1.12.1.5', '1.12.7.2', '1.12.98.1', '1.12.98.4', '1.12.99.6', '1.13.11.17', '1.13.11.18', '1.13.11.20', '1.13.11.52', '1.13.11.55', '1.13.11.79', '1.13.12.1', '1.13.12.16', '1.13.12.17', '1.13.12.2', '1.13.12.3', '1.13.12.4', '1.13.12.8', '1.13.12.9', '1.13.99.1', '1.14.11.1', '1.14.11.13', '1.14.11.66', '1.14.11.67', '1.14.12.10', '1.14.12.12', '1.14.12.13', '1.14.12.14', '1.14.12.15', '1.14.12.16', '1.14.12.17', '1.14.12.18', '1.14.12.22', '1.14.12.24', '1.14.12.3', '1.14.12.7', '1.14.12.8', '1.14.12.9', '1.14.13.1', '1.14.13.10', '1.14.13.101', '1.14.13.105', '1.14.13.107', '1.14.13.111', '1.14.13.113', '1.14.13.114', '1.14.13.130', '1.14.13.131', '1.14.13.135', '1.14.13.148', '1.14.13.149', '1.14.13.153', '1.14.13.16', '1.14.13.160', '1.14.13.161', '1.14.13.163', '1.14.13.166', '1.14.13.167', '1.14.13.168', '1.14.13.170', '1.14.13.171', '1.14.13.18', '1.14.13.180', '1.14.13.182', '1.14.13.187', '1.14.13.19', '1.14.13.195', '1.14.13.196', '1.14.13.2', '1.14.13.20', '1.14.13.200', '1.14.13.208', '1.14.13.210', '1.14.13.211', '1.14.13.212', '1.14.13.215', '1.14.13.216', '1.14.13.217', '1.14.13.218', '1.14.13.22', '1.14.13.222', '1.14.13.223', '1.14.13.224', '1.14.13.225', '1.14.13.23', '1.14.13.231', '1.14.13.232', '1.14.13.233', '1.14.13.236', '1.14.13.237', '1.14.13.238', '1.14.13.239', '1.14.13.24', '1.14.13.240', '1.14.13.241', '1.14.13.242', '1.14.13.243', '1.14.13.244', '1.14.13.25', '1.14.13.27', '1.14.13.29', '1.14.13.31', '1.14.13.32', '1.14.13.33', '1.14.13.35', '1.14.13.39', '1.14.13.4', '1.14.13.40', '1.14.13.44', '1.14.13.5', '1.14.13.50', '1.14.13.54', '1.14.13.58', '1.14.13.59', '1.14.13.6', '1.14.13.61', '1.14.13.63', '1.14.13.64', '1.14.13.69', '1.14.13.7', '1.14.13.8', '1.14.13.83', '1.14.13.84', '1.14.13.9', '1.14.13.92', '1.14.13.B1', '1.14.14.1', '1.14.14.10', '1.14.14.105', '1.14.14.108', '1.14.14.11', '1.14.14.12', '1.14.14.13', '1.14.14.133', '1.14.14.14', '1.14.14.143', '1.14.14.144', '1.14.14.145', '1.14.14.15', '1.14.14.154', '1.14.14.155', '1.14.14.17', '1.14.14.20', '1.14.14.21', '1.14.14.22', '1.14.14.27', '1.14.14.28', '1.14.14.3', '1.14.14.30', '1.14.14.33', '1.14.14.34', '1.14.14.35', '1.14.14.47', '1.14.14.5', '1.14.14.51', '1.14.14.52', '1.14.14.8', '1.14.14.83', '1.14.14.86', '1.14.14.9', '1.14.14.91', '1.14.14.92', '1.14.14.93', '1.14.14.95', '1.14.14.99', '1.14.15.1', '1.14.15.21', '1.14.15.24', '1.14.15.3', '1.14.15.30', '1.14.17.3', '1.14.19.1', '1.14.19.13', '1.14.19.14', '1.14.19.16', '1.14.19.17', '1.14.19.2', '1.14.19.22', '1.14.19.23', '1.14.19.25', '1.14.19.28', '1.14.19.3', '1.14.19.30', '1.14.19.31', '1.14.19.33', '1.14.19.34', '1.14.19.35', '1.14.19.36', '1.14.19.39', '1.14.19.4', '1.14.19.42', '1.14.19.43', '1.14.19.44', '1.14.19.45', '1.14.19.46', '1.14.19.47', '1.14.19.49', '1.14.19.55', '1.14.19.56', '1.14.19.57', '1.14.19.58', '1.14.1 ...
