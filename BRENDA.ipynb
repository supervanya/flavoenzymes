# %%
import pandas as pd
from io import StringIO
import requests
import lxml
import importlib
import json

import importlib
import cache
importlib.reload(cache)

from helpers import print_percent_done

# %% [markdown]
# ### TODO
# -

# %% [markdown]
# ### Configurables
# Edit the folling options before running the scraper
# 1. Add the terms to search for on Brenda's website here:
# 1. Make sure the output and input files are what you want
# 1. Update the blacklist if new errors arise

# %%
useCaching = True # setting this parameter to False will fetch new data from server, instead of using cache
blacklist = [
    # ec number for which requests should not be done (Brenda has some corrupt data)
    # if you run the script and find some ECs produce errors, add them to this list
    '1.1.1.205',
    '1.1.99.15',
    '1.13.11.32',
    '1.14.19.7',
    '1.14.99.40',
    '1.14.99.7',
    '1.3.3.6',
    '1.3.99.B12',
    '1.4.99.B4',
    '1.5.1.29',
    '1.6.8.1',
    '1.6.8.2',
    '1.7.99.5',
    '1.8.1.B1',
    '1.8.99.B1',
    '2.5.1.77',
    '2.7.7.95',
    '3.4.16.4',
    '3.4.21.1',
    '3.4.21.109',
    '3.4.22.3',
    '3.4.22.56',
    '3.4.22.61',
    '3.4.24.15',
    '3.4.24.59',
    '3.4.24.69',
    '7.2.1.1'
]
terms = ['FAD','FMN','flavoenzyme','flavin', 'flavoprotein']
import_file = "export/brenda.json"
export_file = "export/brenda_new_export.json" # made the filename different so that old one can not be overriden

# %%
def brenda_request(url):
    headers = {
      "User-Agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.75 Safari/537.36",
      "X-Requested-With": "XMLHttpRequest"
    }
    response = cache.cached_reqest(url, headers=headers, useCaching=useCaching)
    return response

# %%
def search_ligands_brenda(term):
    columns = ['Ligand','EC Number', 'Role', 'Id', 'Structure', 'Discard']
    url = f'https://www.brenda-enzymes.org/result_download.php?a=13&RN=&RNV=1&os=1&pt=&FNV=1&tt=&SYN=&Textmining=&T[0]=2&T[1]=2&V[1]=1&V[2]=2&W[3]={term}&T[3]=2&nolimit=1'
    response = brenda_request(url)
    df = pd.read_csv(StringIO(response), sep='\t', names=columns)
    return df

# %%
def search_enzymes_brenda(term):
    columns = ['EC Number', 'Recommended Name', 'Synonyms', 'Commentary', 'Discard']
    url = f'https://www.brenda-enzymes.org/result_download.php?a=9&RN=&RNV=1&os=1&pt=&FNV=&tt=&SYN=&Textmining=&T[0]=2&T[1]=2&W[2]={term}&T[2]=2&nolimit=1'    
    response = brenda_request(url)
    df = pd.read_csv(StringIO(response), sep='\t', names=columns)
    return df

# %%
def brenda_get_enzyme_data(id):
    link = f'https://www.brenda-enzymes.info/enzyme.php?ecno={id}#NATURAL%20SUBSTRATE'
    response = brenda_request(link)
    return response

# %%
def search_all_terms(terms, search_fn):
    all_dfs = []

    for term in terms:
        df = search_fn(term)
        if (len(df) < 2):
            print(f'[!] skipping search for {term} since nothing was found')
            continue
        else:
            all_dfs.append(df)
    return pd.concat(all_dfs)

# %%
def get_all_ecs(terms):
    
    enzymes_list = set(search_all_terms(terms,search_enzymes_brenda)['EC Number'])
    ligands_list = set(search_all_terms(terms,search_ligands_brenda)['EC Number'])

    ec_set = enzymes_list | ligands_list
    print(f'total ecs found: {len(ec_set)}')

    return ec_set

# %% [markdown]
# # SOAP helper

# %%
import zeep


from zeep import Client
import hashlib

email = 'si485@dispostable.com'
password = 'si485@dispostable'

wsdl = "https://www.brenda-enzymes.org/soap/brenda_zeep.wsdl"
password = hashlib.sha256(password.encode("utf-8")).hexdigest()
client = Client(wsdl)

# %%
poster_child = '1.14.13.2'

# %%
def brendaSOAP(parameters, fn_name):
    fn = client.service[fn_name]
    client.settings.strict = True
    return cache.brenda_cached_reqest(request_name=f'brenda_{fn_name}', params=parameters, request_fn=fn, useCaching=useCaching)

def getSynonyms(ecNumber):
    parameters = (email, password, f"ecNumber*{ecNumber}", 'organism*', 'synonyms*', 'commentary*', 'literature*')
    resp = brendaSOAP(parameters, 'getSynonyms')
    return sorted({synonym['synonyms'] for synonym in resp})

def getReactions(ecNumber):
    parameters = (email, password,f"ecNumber*{ecNumber}", "reaction*", "commentary*", "literature*", "organism*")
    resp = brendaSOAP(parameters, 'getReaction')
    return sorted({reaction['reaction'] for reaction in resp})

def getSystematicName(ecNumber):
    parameters = (email, password,f"ecNumber*{ecNumber}", "organism*", "systematicName*")
    resp = brendaSOAP(parameters, 'getSystematicName')
    return resp[0]['systematicName'] # there should be only one sysname per entry

def getSubstrate(ecNumber):
    parameters = (email, password,f"ecNumber*{ecNumber}", "organism*", "substrate*", "reactionPartners*", "ligandStructureId*")
    resp = brendaSOAP(parameters,'getSubstrate')
    return sorted({substrate['substrate'] for substrate in resp})

def getProduct(ecNumber):
    parameters = (email, password,f"ecNumber*{ecNumber}", "organism*", "product*", "reactionPartners*", "ligandStructureId*")
    resp = brendaSOAP(parameters,'getProduct')
    return sorted({product['product'] for product in resp})

def getPdb(ecNumber):
    parameters = (email, password,f"ecNumber*{ecNumber}", "organism*", "pdb*")
    resp =  brendaSOAP(parameters,'getPdb')
    return sorted({pdb['pdb'] for pdb in resp})

# %%
all_ecs = get_all_ecs(terms)
# Out:
# Getting cached data...
# https://www.brenda-enzymes.org/result_download.php?a=9&RN=&RNV=1&os=1&pt=&FNV=&tt=&SYN=&Textmining=&T[0]=2&T[1]=2&W[2]=FAD&T[2]=2&nolimit=1
# Getting cached data...
# https://www.brenda-enzymes.org/result_download.php?a=9&RN=&RNV=1&os=1&pt=&FNV=&tt=&SYN=&Textmining=&T[0]=2&T[1]=2&W[2]=FMN&T[2]=2&nolimit=1
# Getting cached data...
# https://www.brenda-enzymes.org/result_download.php?a=9&RN=&RNV=1&os=1&pt=&FNV=&tt=&SYN=&Textmining=&T[0]=2&T[1]=2&W[2]=flavoenzyme&T[2]=2&nolimit=1
# [!] skipping search for flavoenzyme since nothing was found
# Getting cached data...
# https://www.brenda-enzymes.org/result_download.php?a=9&RN=&RNV=1&os=1&pt=&FNV=&tt=&SYN=&Textmining=&T[0]=2&T[1]=2&W[2]=flavin&T[2]=2&nolimit=1
# Getting cached data...
# https://www.brenda-enzymes.org/result_download.php?a=9&RN=&RNV=1&os=1&pt=&FNV=&tt=&SYN=&Textmining=&T[0]=2&T[1]=2&W[2]=flavoprotein&T[2]=2&nolimit=1
# Getting cached data...
# https://www.brenda-enzymes.org/result_download.php?a=13&RN=&RNV=1&os=1&pt=&FNV=1&tt=&SYN=&Textmining=&T[0]=2&T[1]=2&V[1]=1&V[2]=2&W[3]=FAD&T[3]=2&nolimit=1
# Getting cached data...
# https://www.brenda-enzymes.org/result_download.php?a=13&RN=&RNV=1&os=1&pt=&FNV=1&tt=&SYN=&Textmining=&T[0]=2&T[1]=2&V[1]=1&V[2]=2&W[3]=FMN&T[3]=2&nolimit=1
# Getting cached data...
# https://www.brenda-enzymes.org/result_download.php?a=13&RN=&RNV=1&os=1&pt=&FNV=1&tt=&SYN=&Textmining=&T[0]=2&T[1]=2&V[1]=1&V[2]=2&W[3]=flavoenzyme&T[3]=2&nolimit=1
# [!] skipping search for flavoenzyme since nothing was found
# Getting cached data...
# https://www.brenda-enzymes.org/result_download.php?a=13&RN=&RNV=1&os=1&pt=&FNV=1&tt=&SYN=&Textmining=&T[0]=2&T[1]=2&V[1]=1&V[2]=2&W[3]=flavin&T[3]=2&nolimit=1
# Getting cached data...
# https://www.brenda-enzymes.org/result_download.php?a=13&RN=&RNV=1&os=1&pt=&FNV=1&tt=&SYN=&Textmining=&T[0]=2&T[1]=2&V[1]=1&V[2]=2&W[3]=flavoprotein&T[3]=2&nolimit=1
# total ecs found: 808

# %% [markdown]
# ### Initializing BrendaDB

# %%
def read_past_data(path=import_file):
    try:
        with open(path) as json_file:
            return json.load(json_file)
    except:
        return {}

# %%
def create_brenda_ec_entry(ec):
    return {
        'SYSNAME': getSystematicName(ec),
        'REACTIONS': getReactions(ec),
        'SYNONYMS': getSynonyms(ec),
        'SUBSTRATE': getSubstrate(ec),
        'PRODUCT': getProduct(ec),
        'PDB': getPdb(ec),
        'EC_NUMBER': ec
    }

# %%
def create_brenda_db(list_of_ecs, previous_db, verbose=False):
    new_db = previous_db
    for index, ec in enumerate(list_of_ecs):
        if ec not in previous_db and ec not in blacklist:
            if verbose:
                print(f'Fetching data for {ec} ...')
            try:
                entry = create_brenda_ec_entry(ec)
                sysname = entry['SYSNAME']
                entry_name = ec
                new_db[entry_name] = (entry)
                if verbose: 
                    print_percent_done(index=index, length=len(list_of_ecs))
            except Exception as e:
                print(f"[!] couldn't fetch info for {ec}")
                print("     Error: ", e)
                print("\n\n")
                
    # Writing out the results to the file
    with open(export_file, 'w') as outfile:
        json.dump(new_db, outfile)
    print(f'\nSuccessfully written out {len(new_db)} results to "{export_file}"')

    return new_db

# %% [markdown]
# ### Running the Update/Scrape Script

# %%
# Example of the BrendaDB:
# brenda_enzymes = {
#             ecNumber: {
#                 'SYSNAME': "...", # should this be an array?
#                 'REACTIONS': [{reaction},],
#                 'SYNONYMS': ['...',],
#                 'SUBSTRATE': [{substrate},],
#                 'PRODUCT': [{product},],
#                 'PDB': [{pdb}]
#                 'EC_NUMBER': 'ec:1.1.1.1'
#             },
#         }

previous_db = read_past_data(import_file)
sorted_ecs = sorted(list(all_ecs))
db = create_brenda_db(sorted_ecs, previous_db, verbose=True)
# Out:
# Fetching data for 1.1.1.1 ...
#
#
# ----> Progress: ░░░░░░░░░░ 	0% done
# Fetching data for 1.1.1.125 ...
#
#
# ----> Progress: ░░░░░░░░░░ 	0% done
# Fetching data for 1.1.1.181 ...
#
#
# ----> Progress: ░░░░░░░░░░ 	0% done
# Fetching data for 1.1.1.184 ...
#
#
# ----> Progress: ░░░░░░░░░░ 	0% done
# Fetching data for 1.1.1.189 ...
#
#
# ----> Progress: ░░░░░░░░░ 	1% done
# Fetching data for 1.1.1.193 ...
#
#
# ----> Progress: ░░░░░░░░░ 	1% done
# Fetching data for 1.1.1.215 ...
#
#
# ----> Progress: ░░░░░░░░░ 	1% done
# Fetching data for 1.1.1.216 ...
#
#
# ----> Progress: ░░░░░░░░░ 	1% done
# Fetching data for 1.1.1.217 ...
#
#
# ----> Progress: ░░░░░░░░░ 	1% done
# Fetching data for 1.1.1.229 ...
#
#
# ----> Progress: ░░░░░░░░░ 	1% done
# Fetching data for 1.1.1.25 ...
#
#
# ----> Progress: ░░░░░░░░░ 	1% done
# Fetching data for 1.1.1.267 ...
#
#
# ----> Progress: ░░░░░░░░░ 	2% done
# Fetching data for 1.1.1.27 ...
#
#
# ----> Progress: ░░░░░░░░░ 	2% done
# Fetching data for 1.1.1.28 ...
#
#
# ----> Progress: ░░░░░░░░░ 	2% done
# Fetching data for 1.1.1.284 ...
#
#
# ----> Progress: ░░░░░░░░░ 	2% done
# Fetching data for 1.1.1.289 ...
#
#
# ----> Progress: ░░░░░░░░░ 	2% done
# Fetching data for 1.1.1.306 ...
#
#
# ----> Progress: ░░░░░░░░░ 	2% done
# Fetching data for 1.1.1.328 ...
#
#
# ----> Progress: ░░░░░░░░░ 	2% done
# Fetching data for 1.1.1.35 ...
#
#
# ----> Progress: ░░░░░░░░░ 	2% done
# Fetching data for 1.1.1.404 ...
#
#
# ----> Progress: ░░░░░░░░░ 	3% done
# Fetching data for 1.1.1.47 ...
#
#
# ----> Progress: ░░░░░░░░░ 	3% done
# Fetching data for 1.1.1.94 ...
#
#
# ----> Progress: ░░░░░░░░░ 	3% done
# Fetching data for 1.1.1.B3 ...
#
#
# ----> Progress: ░░░░░░░░░ 	3% done
# Fetching data for 1.1.1.B58 ...
#
#
# ----> Progress: ░░░░░░░░░ 	3% done
# Fetching data for 1.1.2.3 ...
#
#
# ----> Progress: ░░░░░░░░░ 	3% done
# Fetching data for 1.1.2.4 ...
#
#
# ----> Progress: ░░░░░░░░░ 	3% done
# Fetching data for 1.1.3.10 ...
#
#
# ----> Progress: ░░░░░░░░░ 	3% done
# Fetching data for 1.1.3.12 ...
#
#
# ----> Progress: ░░░░░░░░░ 	4% done
# Fetching data for 1.1.3.13 ...
#
#
# ----> Progress: ░░░░░░░░░ 	4% done
# Fetching data for 1.1.3.15 ...
#
#
# ----> Progress: ░░░░░░░░░ 	4% done
# Fetching data for 1.1.3.17 ...
#
#
# ----> Progress: ░░░░░░░░░ 	4% done
# Fetching data for 1.1.3.19 ...
#
#
# ----> Progress: ░░░░░░░░░ 	4% done
# Fetching data for 1.1.3.2 ...
#
#
# ----> Progress: ░░░░░░░░░ 	4% done
# Fetching data for 1.1.3.20 ...
#
#
# ----> Progress: ░░░░░░░░░ 	4% done
# Fetching data for 1.1.3.21 ...
#
#
# ----> Progress: ░░░░░░░░░ 	4% done
# Fetching data for 1.1.3.23 ...
#
#
# ----> Progress: ░░░░░░░░░ 	5% done
# Fetching data for 1.1.3.28 ...
#
#
# ----> Progress: ░░░░░░░░░ 	5% done
# Fetching data for 1.1.3.37 ...
#
#
# ----> Progress: ░░░░░░░░░ 	5% done
# Fetching data for 1.1.3.38 ...
#
#
# ----> Progress: ░░░░░░░░░ 	5% done
# Fetching data for 1.1.3.39 ...
#
#
# ----> Progress: ░░░░░░░░░ 	5% done
# Fetching data for 1.1.3.4 ...
#
#
# ----> Progress: ░░░░░░░░░ 	5% done
# Fetching data for 1.1.3.41 ...
#
#
# ----> Progress: ░░░░░░░░░ 	5% done
# Fetching data for 1.1.3.42 ...
#
#
# ----> Progress: ░░░░░░░░░ 	5% done
# Fetching data for 1.1.3.43 ...
#
#
# ----> Progress: ░░░░░░░░░ 	6% done
# Fetching data for 1.1.3.44 ...
#
#
# ----> Progress: ░░░░░░░░░ 	6% done
# Fetching data for 1.1.3.45 ...
#
#
# ----> Progress: ░░░░░░░░░ 	6% done
# Fetching data for 1.1.3.46 ...
#
#
# ----> Progress: ░░░░░░░░░ 	6% done
# Fetching data for 1.1.3.47 ...
#
#
# ----> Progress: ░░░░░░░░░ 	6% done
# Fetching data for 1.1.3.49 ...
#
#
# ----> Progress: ░░░░░░░░░ 	6% done
# Fetching data for 1.1.3.5 ...
#
#
# ----> Progress: ░░░░░░░░░ 	6% done
# Fetching data for 1.1.3.6 ...
#
#
# ----> Progress: ░░░░░░░░░ 	6% done
# Fetching data for 1.1.3.7 ...
#
#
# ----> Progress: ░░░░░░░░░ 	7% done
# Fetching data for 1.1.3.8 ...
#
#
# ----> Progress: ░░░░░░░░░ 	7% done
# Fetching data for 1.1.3.9 ...
#
#
# ----> Progress: ░░░░░░░░░ 	7% done
# Fetching data for 1.1.5.10 ...
#
#
# ----> Progress: ░░░░░░░░░ 	7% done
# Fetching data for 1.1.5.12 ...
#
#
# ----> Progress: ░░░░░░░░░ 	7% done
# Fetching data for 1.1.5.3 ...
#
#
# ----> Progress: ░░░░░░░░░ 	7% done
# Fetching data for 1.1.5.4 ...
#
#
# ----> Progress: ░░░░░░░░░ 	7% done
# Fetching data for 1.1.5.9 ...
#
#
# ----> Progress: ░░░░░░░░░ 	7% done
# Fetching data for 1.1.98.3 ...
#
#
# ----> Progress: ░░░░░░░░░ 	8% done
# Fetching data for 1.1.98.4 ...
#
#
# ----> Progress: ░░░░░░░░░ 	8% done
# Fetching data for 1.1.99.1 ...
#
#
# ----> Progress: ░░░░░░░░░ 	8% done
# Fetching data for 1.1.99.11 ...
#
#
# ----> Progress: ░░░░░░░░░ 	8% done
# Fetching data for 1.1.99.13 ...
#
#
# ----> Progress: ░░░░░░░░░ 	8% done
# Fetching data for 1.1.99.18 ...
#
#
# ----> Progress: ░░░░░░░░░ 	8% done
# Fetching data for 1.1.99.2 ...
#
#
# ----> Progress: ░░░░░░░░░ 	8% done
# Fetching data for 1.1.99.20 ...
#
#
# ----> Progress: ░░░░░░░░░ 	9% done
# Fetching data for 1.1.99.21 ...
#
#
# ----> Progress: ░░░░░░░░░ 	9% done
# Fetching data for 1.1.99.27 ...
#
#
# ----> Progress: ░░░░░░░░░ 	9% done
# Fetching data for 1.1.99.29 ...
#
#
# ----> Progress: ░░░░░░░░░ 	9% done
# Fetching data for 1.1.99.3 ...
#
#
# ----> Progress: ░░░░░░░░░ 	9% done
# Fetching data for 1.1.99.31 ...
#
#
# ----> Progress: ░░░░░░░░░ 	9% done
# Fetching data for 1.1.99.37 ...
#
#
# ----> Progress: ░░░░░░░░░ 	9% done
# Fetching data for 1.1.99.39 ...
#
#
# ----> Progress: ░░░░░░░░░ 	9% done
# Fetching data for 1.1.99.4 ...
#
#
# ----> Progress: █░░░░░░░░░ 	10% done
# Fetching data for 1.1.99.40 ...
#
#
# ----> Progress: █░░░░░░░░░ 	10% done
# Fetching data for 1.1.99.42 ...
#
#
# ----> Progress: █░░░░░░░░░ 	10% done
# Fetching data for 1.1.99.6 ...
#
#
# ----> Progress: █░░░░░░░░░ 	10% done
# Fetching data for 1.1.99.9 ...
#
#
# ----> Progress: █░░░░░░░░░ 	10% done
# Fetching data for 1.1.99.B1 ...
#
#
# ----> Progress: █░░░░░░░░░ 	10% done
# Fetching data for 1.1.99.B3 ...
#
#
# ----> Progress: █░░░░░░░░░ 	10% done
# Fetching data for 1.1.99.B9 ...
#
#
# ----> Progress: █░░░░░░░░░ 	10% done
# Fetching data for 1.10.3.16 ...
#
#
# ----> Progress: █░░░░░░░░ 	11% done
# Fetching data for 1.10.3.4 ...
#
#
# ----> Progress: █░░░░░░░░ 	11% done
# Fetching data for 1.10.3.6 ...
#
#
# ----> Progress: █░░░░░░░░ 	11% done
# Fetching data for 1.10.5.1 ...
#
#
# ----> Progress: █░░░░░░░░ 	11% done
# Fetching data for 1.11.1.1 ...
#
#
# ----> Progress: █░░░░░░░░ 	11% done
# Fetching data for 1.11.1.17 ...
#
#
# ----> Progress: █░░░░░░░░ 	11% done
# Fetching data for 1.11.1.23 ...
#
#
# ----> Progress: █░░░░░░░░ 	11% done
# Fetching data for 1.12.1.2 ...
#
#
# ----> Progress: █░░░░░░░░ 	11% done
# Fetching data for 1.12.1.3 ...
#
#
# ----> Progress: █░░░░░░░░ 	12% done
# Fetching data for 1.12.1.4 ...
#
#
# ----> Progress: █░░░░░░░░ 	12% done
# Fetching data for 1.12.1.5 ...
#
#
# ----> Progress: █░░░░░░░░ 	12% done
# Fetching data for 1.12.7.2 ...
#
#
# ----> Progress: █░░░░░░░░ 	12% done
# Fetching data for 1.12.98.1 ...
#
#
# ----> Progress: █░░░░░░░░ 	12% done
# Fetching data for 1.12.98.4 ...
#
#
# ----> Progress: █░░░░░░░░ 	12% done
# Fetching data for 1.12.99.6 ...
#
#
# ----> Progress: █░░░░░░░░ 	12% done
# Fetching data for 1.13.11.17 ...
#
#
# ----> Progress: █░░░░░░░░ 	12% done
# Fetching data for 1.13.11.18 ...
#
#
# ----> Progress: █░░░░░░░░ 	12% done
# Fetching data for 1.13.11.20 ...
#
#
# ----> Progress: █░░░░░░░░ 	13% done
# Fetching data for 1.13.11.52 ...
#
#
# ----> Progress: █░░░░░░░░ 	13% done
# Fetching data for 1.13.11.55 ...
#
#
# ----> Progress: █░░░░░░░░ 	13% done
# Fetching data for 1.13.11.79 ...
#
#
# ----> Progress: █░░░░░░░░ 	13% done
# Fetching data for 1.13.12.1 ...
#
#
# ----> Progress: █░░░░░░░░ 	13% done
# Fetching data for 1.13.12.16 ...
#
#
# ----> Progress: █░░░░░░░░ 	13% done
# Fetching data for 1.13.12.17 ...
#
#
# ----> Progress: █░░░░░░░░ 	13% done
# Fetching data for 1.13.12.2 ...
#
#
# ----> Progress: █░░░░░░░░ 	14% done
# Fetching data for 1.13.12.3 ...
#
#
# ----> Progress: █░░░░░░░░ 	14% done
# Fetching data for 1.13.12.4 ...
#
#
# ----> Progress: █░░░░░░░░ 	14% done
# Fetching data for 1.13.12.8 ...
#
#
# ----> Progress: █░░░░░░░░ 	14% done
# Fetching data for 1.13.12.9 ...
#
#
# ----> Progress: █░░░░░░░░ 	14% done
# Fetching data for 1.13.99.1 ...
#
#
# ----> Progress: █░░░░░░░░ 	14% done
# Fetching data for 1.14.11.1 ...
#
#
# ----> Progress: █░░░░░░░░ 	14% done
# Fetching data for 1.14.11.13 ...
#
#
# ----> Progress: █░░░░░░░░ 	14% done
# Fetching data for 1.14.11.66 ...
#
#
# ----> Progress: █░░░░░░░░ 	15% done
# Fetching data for 1.14.11.67 ...
#
#
# ----> Progress: █░░░░░░░░ 	15% done
# Fetching data for 1.14.12.10 ...
#
#
# ----> Progress: █░░░░░░░░ 	15% done
# Fetching data for 1.14.12.11 ...
#
#
# ----> Progress: █░░░░░░░░ 	15% done
# Fetching data for 1.14.12.12 ...
#
#
# ----> Progress: █░░░░░░░░ 	15% done
# Fetching data for 1.14.12.13 ...
#
#
# ----> Progress: █░░░░░░░░ 	15% done
# Fetching data for 1.14.12.14 ...
#
#
# ----> Progress: █░░░░░░░░ 	15% done
# Fetching data for 1.14.12.15 ...
#
#
# ----> Progress: █░░░░░░░░ 	15% done
# Fetching data for 1.14.12.16 ...
#
#
# ----> Progress: █░░░░░░░░ 	16% done
# Fetching data for 1.14.12.17 ...
#
#
# ----> Progress: █░░░░░░░░ 	16% done
# Fetching data for 1.14.12.18 ...
#
#
# ----> Progress: █░░░░░░░░ 	16% done
# Fetching data for 1.14.12.22 ...
#
#
# ----> Progress: █░░░░░░░░ 	16% done
# Fetching data for 1.14.12.24 ...
#
#
# ----> Progress: █░░░░░░░░ 	16% done
# Fetching data for 1.14.12.3 ...
#
#
# ----> Progress: █░░░░░░░░ 	16% done
# Fetching data for 1.14.12.7 ...
#
#
# ----> Progress: █░░░░░░░░ 	16% done
# Fetching data for 1.14.12.8 ...
#
#
# ----> Progress: █░░░░░░░░ 	16% done
# Fetching data for 1.14.12.9 ...
#
#
# ----> Progress: █░░░░░░░░ 	17% done
# Fetching data for 1.14.13.1 ...
#
#
# ----> Progress: █░░░░░░░░ 	17% done
# Fetching data for 1.14.13.10 ...
#
#
# ----> Progress: █░░░░░░░░ 	17% done
# Fetching data for 1.14.13.101 ...
#
#
# ----> Progress: █░░░░░░░░ 	17% done
# Fetching data for 1.14.13.105 ...
#
#
# ----> Progress: █░░░░░░░░ 	17% done
# Fetching data for 1.14.13.107 ...
#
#
# ----> Progress: █░░░░░░░░ 	17% done
# Fetching data for 1.14.13.111 ...
#
#
# ----> Progress: █░░░░░░░░ 	17% done
# Fetching data for 1.14.13.113 ...
#
#
# ----> Progress: █░░░░░░░░ 	17% done
# Fetching data for 1.14.13.114 ...
#
#
# ----> Progress: █░░░░░░░░ 	18% done
# Fetching data for 1.14.13.127 ...
#
#
# ----> Progress: █░░░░░░░░ 	18% done
# Fetching data for 1.14.13.130 ...
#
#
# ----> Progress: █░░░░░░░░ 	18% done
# Fetching data for 1.14.13.131 ...
#
#
# ----> Progress: █░░░░░░░░ 	18% done
# Fetching data for 1.14.13.135 ...
#
#
# ----> Progress: █░░░░░░░░ 	18% done
# Fetching data for 1.14.13.148 ...
#
#
# ----> Progress: █░░░░░░░░ 	18% done
# Fetching data for 1.14.13.149 ...
#
#
# ----> Progress: █░░░░░░░░ 	18% done
# Fetching data for 1.14.13.153 ...
#
#
# ----> Progress: █░░░░░░░░ 	18% done
# Fetching data for 1.14.13.16 ...
#
#
# ----> Progress: █░░░░░░░░ 	19% done
# Fetching data for 1.14.13.160 ...
#
#
# ----> Progress: █░░░░░░░░ 	19% done
# Fetching data for 1.14.13.161 ...
#
#
# ----> Progress: █░░░░░░░░ 	19% done
# Fetching data for 1.14.13.163 ...
#
#
# ----> Progress: █░░░░░░░░ 	19% done
# Fetching data for 1.14.13.166 ...
#
#
# ----> Progress: █░░░░░░░░ 	19% done
# Fetching data for 1.14.13.167 ...
#
#
# ----> Progress: █░░░░░░░░ 	19% done
# Fetching data for 1.14.13.168 ...
#
#
# ----> Progress: █░░░░░░░░ 	19% done
# Fetching data for 1.14.13.170 ...
#
#
# ----> Progress: █░░░░░░░░ 	19% done
# Fetching data for 1.14.13.171 ...
#
#
# ----> Progress: ██░░░░░░░░ 	20% done
# Fetching data for 1.14.13.18 ...
#
#
# ----> Progress: ██░░░░░░░░ 	20% done
# Fetching data for 1.14.13.180 ...
#
#
# ----> Progress: ██░░░░░░░░ 	20% done
# Fetching data for 1.14.13.182 ...
#
#
# ----> Progress: ██░░░░░░░░ 	20% done
# Fetching data for 1.14.13.187 ...
#
#
# ----> Progress: ██░░░░░░░░ 	20% done
# Fetching data for 1.14.13.19 ...
#
#
# ----> Progress: ██░░░░░░░░ 	20% done
# Fetching data for 1.14.13.195 ...
#
#
# ----> Progress: ██░░░░░░░░ 	20% done
# Fetching data for 1.14.13.196 ...
#
#
# ----> Progress: ██░░░░░░░░ 	20% done
# Fetching data for 1.14.13.2 ...
#
#
# ----> Progress: ██░░░░░░░ 	21% done
# Fetching data for 1.14.13.20 ...
#
#
# ----> Progress: ██░░░░░░░ 	21% done
# Fetching data for 1.14.13.200 ...
#
#
# ----> Progress: ██░░░░░░░ 	21% done
# Fetching data for 1.14.13.208 ...
#
#
# ----> Progress: ██░░░░░░░ 	21% done
# Fetching data for 1.14.13.210 ...
#
#
# ----> Progress: ██░░░░░░░ 	21% done
# Fetching data for 1.14.13.211 ...
#
#
# ----> Progress: ██░░░░░░░ 	21% done
# Fetching data for 1.14.13.212 ...
#
#
# ----> Progress: ██░░░░░░░ 	21% done
# Fetching data for 1.14.13.215 ...
#
#
# ----> Progress: ██░░░░░░░ 	21% done
# Fetching data for 1.14.13.216 ...
#
#
# ----> Progress: ██░░░░░░░ 	22% done
# Fetching data for 1.14.13.217 ...
#
#
# ----> Progress: ██░░░░░░░ 	22% done
# Fetching data for 1.14.13.218 ...
#
#
# ----> Progress: ██░░░░░░░ 	22% done
# Fetching data for 1.14.13.22 ...
#
#
# ----> Progress: ██░░░░░░░ 	22% done
# Fetching data for 1.14.13.222 ...
#
#
# ----> Progress: ██░░░░░░░ 	22% done
# Fetching data for 1.14.13.223 ...
#
#
# ----> Progress: ██░░░░░░░ 	22% done
# Fetching data for 1.14.13.224 ...
#
#
# ----> Progress: ██░░░░░░░ 	22% done
# Fetching data for 1.14.13.225 ...
#
#
# ----> Progress: ██░░░░░░░ 	22% done
# Fetching data for 1.14.13.23 ...
#
#
# ----> Progress: ██░░░░░░░ 	23% done
# Fetching data for 1.14.13.231 ...
#
#
# ----> Progress: ██░░░░░░░ 	23% done
# Fetching data for 1.14.13.232 ...
#
#
# ----> Progress: ██░░░░░░░ 	23% done
# Fetching data for 1.14.13.233 ...
#
#
# ----> Progress: ██░░░░░░░ 	23% done
# Fetching data for 1.14.13.236 ...
#
#
# ----> Progress: ██░░░░░░░ 	23% done
# Fetching data for 1.14.13.237 ...
#
#
# ----> Progress: ██░░░░░░░ 	23% done
# Fetching data for 1.14.13.238 ...
#
#
# ----> Progress: ██░░░░░░░ 	23% done
# Fetching data for 1.14.13.239 ...
#
#
# ----> Progress: ██░░░░░░░ 	23% done
# Fetching data for 1.14.13.24 ...
#
#
# ----> Progress: ██░░░░░░░ 	24% done
# Fetching data for 1.14.13.240 ...
#
#
# ----> Progress: ██░░░░░░░ 	24% done
# Fetching data for 1.14.13.241 ...
#
#
# ----> Progress: ██░░░░░░░ 	24% done
# Fetching data for 1.14.13.242 ...
#
#
# ----> Progress: ██░░░░░░░ 	24% done
# Fetching data for 1.14.13.243 ...
#
#
# ----> Progress: ██░░░░░░░ 	24% done
# Fetching data for 1.14.13.244 ...
#
#
# ----> Progress: ██░░░░░░░ 	24% done
# Fetching data for 1.14.13.25 ...
#
#
# ----> Progress: ██░░░░░░░ 	24% done
# Fetching data for 1.14.13.27 ...
#
#
# ----> Progress: ██░░░░░░░ 	24% done
# Fetching data for 1.14.13.29 ...
#
#
# ----> Progress: ██░░░░░░░ 	25% done
# Fetching data for 1.14.13.31 ...
#
#
# ----> Progress: ██░░░░░░░ 	25% done
# Fetching data for 1.14.13.32 ...
#
#
# ----> Progress: ██░░░░░░░ 	25% done
# Fetching data for 1.14.13.33 ...
#
#
# ----> Progress: ██░░░░░░░ 	25% done
# Fetching data for 1.14.13.35 ...
#
#
# ----> Progress: ██░░░░░░░ 	25% done
# Fetching data for 1.14.13.39 ...
#
#
# ----> Progress: ██░░░░░░░ 	25% done
# Fetching data for 1.14.13.4 ...
#
#
# ----> Progress: ██░░░░░░░ 	25% done
# Fetching data for 1.14.13.40 ...
#
#
# ----> Progress: ██░░░░░░░ 	25% done
# Fetching data for 1.14.13.44 ...
#
#
# ----> Progress: ██░░░░░░░ 	25% done
# Fetching data for 1.14.13.5 ...
#
#
# ----> Progress: ██░░░░░░░ 	26% done
# Fetching data for 1.14.13.50 ...
#
#
# ----> Progress: ██░░░░░░░ 	26% done
# Fetching data for 1.14.13.54 ...
#
#
# ----> Progress: ██░░░░░░░ 	26% done
# Fetching data for 1.14.13.58 ...
#
#
# ----> Progress: ██░░░░░░░ 	26% done
# Fetching data for 1.14.13.59 ...
#
#
# ----> Progress: ██░░░░░░░ 	26% done
# Fetching data for 1.14.13.6 ...
#
#
# ----> Progress: ██░░░░░░░ 	26% done
# Fetching data for 1.14.13.61 ...
#
#
# ----> Progress: ██░░░░░░░ 	26% done
# Fetching data for 1.14.13.63 ...
#
#
# ----> Progress: ██░░░░░░░ 	26% done
# Fetching data for 1.14.13.64 ...
#
#
# ----> Progress: ██░░░░░░░ 	27% done
# Fetching data for 1.14.13.69 ...
#
#
# ----> Progress: ██░░░░░░░ 	27% done
# Fetching data for 1.14.13.7 ...
#
#
# ----> Progress: ██░░░░░░░ 	27% done
# Fetching data for 1.14.13.8 ...
#
#
# ----> Progress: ██░░░░░░░ 	27% done
# Fetching data for 1.14.13.83 ...
#
#
# ----> Progress: ██░░░░░░░ 	27% done
# Fetching data for 1.14.13.84 ...
#
#
# ----> Progress: ██░░░░░░░ 	27% done
# Fetching data for 1.14.13.9 ...
#
#
# ----> Progress: ██░░░░░░░ 	27% done
# Fetching data for 1.14.13.92 ...
#
#
# ----> Progress: ██░░░░░░░ 	27% done
# Fetching data for 1.14.13.B1 ...
#
#
# ----> Progress: ██░░░░░░░ 	28% done
# Fetching data for 1.14.14.1 ...
#
#
# ----> Progress: ██░░░░░░░ 	28% done
# Fetching data for 1.14.14.10 ...
#
#
# ----> Progress: ██░░░░░░░ 	28% done
# Fetching data for 1.14.14.105 ...
#
#
# ----> Progress: ██░░░░░░░ 	28% done
# Fetching data for 1.14.14.108 ...
#
#
# ----> Progress: ██░░░░░░░ 	28% done
# Fetching data for 1.14.14.11 ...
#
#
# ----> Progress: ██░░░░░░░ 	28% done
# Fetching data for 1.14.14.12 ...
#
#
# ----> Progress: ██░░░░░░░ 	28% done
# Fetching data for 1.14.14.13 ...
#
#
# ----> Progress: ██░░░░░░░ 	28% done
# Fetching data for 1.14.14.133 ...
#
#
# ----> Progress: ██░░░░░░░ 	29% done
# Fetching data for 1.14.14.14 ...
#
#
# ----> Progress: ██░░░░░░░ 	29% done
# Fetching data for 1.14.14.143 ...
#
#
# ----> Progress: ██░░░░░░░ 	29% done
# Fetching data for 1.14.14.144 ...
#
#
# ----> Progress: ██░░░░░░░ 	29% done
# Fetching data for 1.14.14.145 ...
#
#
# ----> Progress: ██░░░░░░░ 	29% done
# Fetching data for 1.14.14.15 ...
#
#
# ----> Progress: ██░░░░░░░ 	29% done
# Fetching data for 1.14.14.154 ...
#
#
# ----> Progress: ██░░░░░░░ 	29% done
# Fetching data for 1.14.14.155 ...
#
#
# ----> Progress: ██░░░░░░░ 	29% done
# Fetching data for 1.14.14.17 ...
#
#
# ----> Progress: ███░░░░░░░ 	30% done
# Fetching data for 1.14.14.20 ...
#
#
# ----> Progress: ███░░░░░░░ 	30% done
# Fetching data for 1.14.14.21 ...
#
#
# ----> Progress: ███░░░░░░░ 	30% done
# Fetching data for 1.14.14.22 ...
#
#
# ----> Progress: ███░░░░░░░ 	30% done
# Fetching data for 1.14.14.27 ...
#
#
# ----> Progress: ███░░░░░░░ 	30% done
# Fetching data for 1.14.14.28 ...
#
#
# ----> Progress: ███░░░░░░░ 	30% done
# Fetching data for 1.14.14.3 ...
#
#
# ----> Progress: ███░░░░░░░ 	30% done
# Fetching data for 1.14.14.30 ...
#
#
# ----> Progress: ███░░░░░░░ 	30% done
# Fetching data for 1.14.14.33 ...
#
#
# ----> Progress: ███░░░░░░ 	31% done
# Fetching data for 1.14.14.34 ...
#
#
# ----> Progress: ███░░░░░░ 	31% done
# Fetching data for 1.14.14.35 ...
#
#
# ----> Progress: ███░░░░░░ 	31% done
# Fetching data for 1.14.14.47 ...
#
#
# ----> Progress: ███░░░░░░ 	31% done
# Fetching data for 1.14.14.5 ...
#
#
# ----> Progress: ███░░░░░░ 	31% done
# Fetching data for 1.14.14.51 ...
#
#
# ----> Progress: ███░░░░░░ 	31% done
# Fetching data for 1.14.14.52 ...
#
#
# ----> Progress: ███░░░░░░ 	31% done
# Fetching data for 1.14.14.8 ...
#
#
# ----> Progress: ███░░░░░░ 	31% done
# Fetching data for 1.14.14.83 ...
#
#
# ----> Progress: ███░░░░░░ 	32% done
# Fetching data for 1.14.14.86 ...
#
#
# ----> Progress: ███░░░░░░ 	32% done
# Fetching data for 1.14.14.9 ...
#
#
# ----> Progress: ███░░░░░░ 	32% done
# Fetching data for 1.14.14.91 ...
#
#
# ----> Progress: ███░░░░░░ 	32% done
# Fetching data for 1.14.14.92 ...
#
#
# ----> Progress: ███░░░░░░ 	32% done
# Fetching data for 1.14.14.93 ...
#
#
# ----> Progress: ███░░░░░░ 	32% done
# Fetching data for 1.14.14.95 ...
#
#
# ----> Progress: ███░░░░░░ 	32% done
# Fetching data for 1.14.14.99 ...
#
#
# ----> Progress: ███░░░░░░ 	32% done
# Fetching data for 1.14.15.1 ...
#
#
# ----> Progress: ███░░░░░░ 	33% done
# Fetching data for 1.14.15.21 ...
#
#
# ----> Progress: ███░░░░░░ 	33% done
# Fetching data for 1.14.15.24 ...
#
#
# ----> Progress: ███░░░░░░ 	33% done
# Fetching data for 1.14.15.3 ...
#
#
# ----> Progress: ███░░░░░░ 	33% done
# Fetching data for 1.14.15.30 ...
#
#
# ----> Progress: ███░░░░░░ 	33% done
# Fetching data for 1.14.15.4 ...
#
#
# ----> Progress: ███░░░░░░ 	33% done
# Fetching data for 1.14.17.3 ...
#
#
# ----> Progress: ███░░░░░░ 	33% done
# Fetching data for 1.14.19.1 ...
#
#
# ----> Progress: ███░░░░░░ 	33% done
# Fetching data for 1.14.19.13 ...
#
#
# ----> Progress: ███░░░░░░ 	34% done
# Fetching data for 1.14.19.14 ...
#
#
# ----> Progress: ███░░░░░░ 	34% done
# Fetching data for 1.14.19.16 ...
#
#
# ----> Progress: ███░░░░░░ 	34% done
# Fetching data for 1.14.19.17 ...
#
#
# ----> Progress: ███░░░░░░ 	34% done
# Fetching data for 1.14.19.2 ...
#
#
# ----> Progress: ███░░░░░░ 	34% done
# Fetching data for 1.14.19.22 ...
#
#
# ----> Progress: ███░░░░░░ 	34% done
# Fetching data for 1.14.19.23 ...
#
#
# ----> Progress: ███░░░░░░ 	34% done
# Fetching data for 1.14.19.25 ...
#
#
# ----> Progress: ███░░░░░░ 	34% done
# Fetching data for 1.14.19.28 ...
#
#
# ----> Progress: ███░░░░░░ 	35% done
# Fetching data for 1.14.19.3 ...
#
#
# ----> Progress: ███░░░░░░ 	35% done
# Fetching data for 1.14.19.30 ...
#
#
# ----> Progress: ███░░░░░░ 	35% done
# Fetching data for 1.14.19.31 ...
#
#
# ----> Progress: ███░░░░░░ 	35% done
# Fetching data for 1.14.19.33 ...
#
#
# ----> Progress: ███░░░░░░ 	35% done
# Fetching data for 1.14.19.34 ...
#
#
# ----> Progress: ███░░░░░░ 	35% done
# Fetching data for 1.14.19.35 ...
#
#
# ----> Progress: ███░░░░░░ 	35% done
# Fetching data for 1.14.19.36 ...
#
#
# ----> Progress: ███░░░░░░ 	35% done
# Fetching data for 1.14.19.39 ...
#
#
# ----> Progress: ███░░░░░░ 	36% done
# Fetching data for 1.14.19.4 ...
#
#
# ----> Progress: ███░░░░░░ 	36% done
# Fetching data for 1.14.19.42 ...
#
#
# ----> Progress: ███░░░░░░ 	36% done
# Fetching data for 1.14.19.43 ...
#
#
# ----> Progress: ███░░░░░░ 	36% done
# Fetching data for 1.14.19.44 ...
#
#
# ----> Progress: ███░░░░░░ 	36% done
# Fetching data for 1.14.19.45 ...
#
#
# ----> Progress: ███░░░░░░ 	36% done
# Fetching data for 1.14.19.46 ...
#
#
# ----> Progress: ███░░░░░░ 	36% done
# Fetching data for 1.14.19.47 ...
#
#
# ----> Progress: ███░░░░░░ 	36% done
# Fetching data for 1.14.19.49 ...
#
#
# ----> Progress: ███░░░░░░ 	37% done
# Fetching data for 1.14.19.55 ...
#
#
# ----> Progress: ███░░░░░░ 	37% done
# Fetching data for 1.14.19.56 ...
#
#
# ----> Progress: ███░░░░░░ 	37% done
# Fetching data for 1.14.19.57 ...
#
#
# ----> Progress: ███░░░░░░ 	37% done
# Fetching data for 1.14.19.58 ...
#
#
# ----> Progress: ███░░░░░░ 	37% done
# Fetching data for 1.14.19.59 ...
#
#
# ----> Progress: ███░░░░░░ 	37% done
# Fetching data for 1.14.19.6 ...
#
#
# ----> Progress: ███░░░░░░ 	37% done
# Fetching data for 1.14.19.60 ...
#
#
# ----> Progress: ███░░░░░░ 	37% done
# Fetching data for 1.14.19.64 ...
#
#
# ----> Progress: ███░░░░░░ 	38% done
# Fetching data for 1.14.19.65 ...
#
#
# ----> Progress: ███░░░░░░ 	38% done
# Fetching data for 1.14.19.9 ...
#
#
# ----> Progress: ███░░░░░░ 	38% done
# Fetching data for 1.14.19.B8 ...
#
#
# ----> Progress: ███░░░░░░ 	38% done
# Fetching data for 1.14.19.B9 ...
#
#
# ----> Progress: ███░░░░░░ 	38% done
# Fetching data for 1.14.99.15 ...
#
#
# ----> Progress: ███░░░░░░ 	38% done
# Fetching data for 1.14.99.21 ...
#
#
# ----> Progress: ███░░░░░░ 	38% done
# Fetching data for 1.14.99.24 ...
#
#
# ----> Progress: ███░░░░░░ 	38% done
# Fetching data for 1.14.99.26 ...
#
#
# ----> Progress: ███░░░░░░ 	39% done
# Fetching data for 1.14.99.34 ...
#
#
# ----> Progress: ███░░░░░░ 	39% done
# Fetching data for 1.14.99.37 ...
#
#
# ----> Progress: ███░░░░░░ 	39% done
# Fetching data for 1.14.99.46 ...
#
#
# ----> Progress: ███░░░░░░ 	39% done
# Fetching data for 1.14.99.66 ...
#
#
# ----> Progress: ███░░░░░░ 	39% done
# Fetching data for 1.15.1.1 ...
#
#
# ----> Progress: ███░░░░░░ 	39% done
# Fetching data for 1.16.1.1 ...
#
#
# ----> Progress: ████░░░░░░ 	40% done
# Fetching data for 1.16.1.10 ...
#
#
# ----> Progress: ████░░░░░░ 	40% done
# Fetching data for 1.16.1.3 ...
#
#
# ----> Progress: ████░░░░░░ 	40% done
# Fetching data for 1.16.1.4 ...
#
#
# ----> Progress: ████░░░░░░ 	40% done
# Fetching data for 1.16.1.5 ...
#
#
# ----> Progress: ████░░░░░░ 	40% done
# Fetching data for 1.16.1.6 ...
#
#
# ----> Progress: ████░░░░░░ 	40% done
# Fetching data for 1.16.1.7 ...
#
#
# ----> Progress: ████░░░░░░ 	40% done
# Fetching data for 1.16.1.8 ...
#
#
# ----> Progress: ████░░░░░░ 	40% done
# Fetching data for 1.16.1.9 ...
#
#
# ----> Progress: ████░░░░░ 	41% done
# Fetching data for 1.16.8.1 ...
#
#
# ----> Progress: ████░░░░░ 	41% done
# Fetching data for 1.17.1.11 ...
#
#
# ----> Progress: ████░░░░░ 	41% done
# Fetching data for 1.17.1.4 ...
#
#
# ----> Progress: ████░░░░░ 	41% done
# Fetching data for 1.17.1.5 ...
#
#
# ----> Progress: ████░░░░░ 	41% done
# Fetching data for 1.17.1.8 ...
#
#
# ----> Progress: ████░░░░░ 	41% done
# Fetching data for 1.17.1.9 ...
#
#
# ----> Progress: ████░░░░░ 	41% done
# Fetching data for 1.17.3.2 ...
#
#
# ----> Progress: ████░░░░░ 	41% done
# Fetching data for 1.17.3.3 ...
#
#
# ----> Progress: ████░░░░░ 	42% done
# Fetching data for 1.17.4.1 ...
#
#
# ----> Progress: ████░░░░░ 	42% done
# Fetching data for 1.17.7.2 ...
#
#
# ----> Progress: ████░░░░░ 	42% done
# Fetching data for 1.17.7.3 ...
#
#
# ----> Progress: ████░░░░░ 	42% done
# Fetching data for 1.17.7.4 ...
#
#
# ----> Progress: ████░░░░░ 	42% done
# Fetching data for 1.17.8.1 ...
#
#
# ----> Progress: ████░░░░░ 	42% done
# Fetching data for 1.17.9.1 ...
#
#
# ----> Progress: ████░░░░░ 	42% done
# Fetching data for 1.17.98.3 ...
#
#
# ----> Progress: ████░░░░░ 	42% done
# Fetching data for 1.17.99.3 ...
#
#
# ----> Progress: ████░░░░░ 	43% done
# Fetching data for 1.17.99.7 ...
#
#
# ----> Progress: ████░░░░░ 	43% done
# Fetching data for 1.18.1.1 ...
#
#
# ----> Progress: ████░░░░░ 	43% done
# Fetching data for 1.18.1.2 ...
#
#
# ----> Progress: ████░░░░░ 	43% done
# Fetching data for 1.18.1.3 ...
#
#
# ----> Progress: ████░░░░░ 	43% done
# Fetching data for 1.18.1.4 ...
#
#
# ----> Progress: ████░░░░░ 	43% done
# Fetching data for 1.18.1.5 ...
#
#
# ----> Progress: ████░░░░░ 	43% done
# Fetching data for 1.18.1.6 ...
#
#
# ----> Progress: ████░░░░░ 	43% done
# Fetching data for 1.18.1.7 ...
#
#
# ----> Progress: ████░░░░░ 	44% done
# Fetching data for 1.19.1.1 ...
#
#
# ----> Progress: ████░░░░░ 	44% done
# Fetching data for 1.2.1.36 ...
#
#
# ----> Progress: ████░░░░░ 	44% done
# Fetching data for 1.2.1.46 ...
#
#
# ----> Progress: ████░░░░░ 	44% done
# Fetching data for 1.2.1.51 ...
#
#
# ----> Progress: ████░░░░░ 	44% done
# Fetching data for 1.2.1.57 ...
#
#
# ----> Progress: ████░░░░░ 	44% done
# Fetching data for 1.2.1.58 ...
#
#
# ----> Progress: ████░░░░░ 	44% done
# Fetching data for 1.2.1.64 ...
#
#
# ----> Progress: ████░░░░░ 	44% done
# Fetching data for 1.2.1.88 ...
#
#
# ----> Progress: ████░░░░░ 	45% done
# Fetching data for 1.2.2.4 ...
#
#
# ----> Progress: ████░░░░░ 	45% done
# Fetching data for 1.2.3.1 ...
#
#
# ----> Progress: ████░░░░░ 	45% done
# Fetching data for 1.2.3.13 ...
#
#
# ----> Progress: ████░░░░░ 	45% done
# Fetching data for 1.2.3.3 ...
#
#
# ----> Progress: ████░░░░░ 	45% done
# Fetching data for 1.2.3.4 ...
#
#
# ----> Progress: ████░░░░░ 	45% done
# Fetching data for 1.2.3.6 ...
#
#
# ----> Progress: ████░░░░░ 	45% done
# Fetching data for 1.2.3.7 ...
#
#
# ----> Progress: ████░░░░░ 	45% done
# Fetching data for 1.2.4.2 ...
#
#
# ----> Progress: ████░░░░░ 	46% done
# Fetching data for 1.2.4.4 ...
#
#
# ----> Progress: ████░░░░░ 	46% done
# Fetching data for 1.2.5.1 ...
#
#
# ----> Progress: ████░░░░░ 	46% done
# Fetching data for 1.2.5.3 ...
#
#
# ----> Progress: ████░░░░░ 	46% done
# Fetching data for 1.2.7.1 ...
#
#
# ----> Progress: ████░░░░░ 	46% done
# Fetching data for 1.2.7.10 ...
#
#
# ----> Progress: ████░░░░░ 	46% done
# Fetching data for 1.2.7.4 ...
#
#
# ----> Progress: ████░░░░░ 	46% done
# Fetching data for 1.2.99.6 ...
#
#
# ----> Progress: ████░░░░░ 	46% done
# Fetching data for 1.2.99.7 ...
#
#
# ----> Progress: ████░░░░░ 	47% done
# Fetching data for 1.2.99.8 ...
#
#
# ----> Progress: ████░░░░░ 	47% done
# Fetching data for 1.21.1.1 ...
#
#
# ----> Progress: ████░░░░░ 	47% done
# Fetching data for 1.21.3.3 ...
#
#
# ----> Progress: ████░░░░░ 	47% done
# Fetching data for 1.21.3.7 ...
#
#
# ----> Progress: ████░░░░░ 	47% done
# Fetching data for 1.21.3.8 ...
#
#
# ----> Progress: ████░░░░░ 	47% done
# Fetching data for 1.21.98.2 ...
#
#
# ----> Progress: ████░░░░░ 	47% done
# Fetching data for 1.21.99.1 ...
#
#
# ----> Progress: ████░░░░░ 	47% done
# Fetching data for 1.3.1.10 ...
#
#
# ----> Progress: ████░░░░░ 	48% done
# Fetching data for 1.3.1.100 ...
#
#
# ----> Progress: ████░░░░░ 	48% done
# Fetching data for 1.3.1.101 ...
#
#
# ----> Progress: ████░░░░░ 	48% done
# Fetching data for 1.3.1.105 ...
#
#
# ----> Progress: ████░░░░░ 	48% done
# Fetching data for 1.3.1.108 ...
#
#
# ----> Progress: ████░░░░░ 	48% done
# Fetching data for 1.3.1.109 ...
#
#
# ----> Progress: ████░░░░░ 	48% done
# Fetching data for 1.3.1.110 ...
#
#
# ----> Progress: ████░░░░░ 	48% done
# Fetching data for 1.3.1.114 ...
#
#
# ----> Progress: ████░░░░░ 	48% done
# Fetching data for 1.3.1.115 ...
#
#
# ----> Progress: ████░░░░░ 	49% done
# Fetching data for 1.3.1.116 ...
#
#
# ----> Progress: ████░░░░░ 	49% done
# Fetching data for 1.3.1.14 ...
#
#
# ----> Progress: ████░░░░░ 	49% done
# Fetching data for 1.3.1.15 ...
#
#
# ----> Progress: ████░░░░░ 	49% done
# Fetching data for 1.3.1.2 ...
#
#
# ----> Progress: ████░░░░░ 	49% done
# Fetching data for 1.3.1.21 ...
#
#
# ----> Progress: ████░░░░░ 	49% done
# Fetching data for 1.3.1.22 ...
#
#
# ----> Progress: ████░░░░░ 	49% done
# Fetching data for 1.3.1.24 ...
#
#
# ----> Progress: ████░░░░░ 	49% done
# Fetching data for 1.3.1.27 ...
#
#
# ----> Progress: █████░░░░░ 	50% done
# Fetching data for 1.3.1.31 ...
#
#
# ----> Progress: █████░░░░░ 	50% done
# Fetching data for 1.3.1.33 ...
#
#
# ----> Progress: █████░░░░░ 	50% done
# Fetching data for 1.3.1.34 ...
#
#
# ----> Progress: █████░░░░░ 	50% done
# Fetching data for 1.3.1.41 ...
#
#
# ----> Progress: █████░░░░░ 	50% done
# Fetching data for 1.3.1.42 ...
#
#
# ----> Progress: █████░░░░░ 	50% done
# Fetching data for 1.3.1.44 ...
#
#
# ----> Progress: █████░░░░░ 	50% done
# Fetching data for 1.3.1.6 ...
#
#
# ----> Progress: █████░░░░░ 	50% done
# Fetching data for 1.3.1.72 ...
#
#
# ----> Progress: █████░░░░░ 	50% done
# Fetching data for 1.3.1.8 ...
#
#
# ----> Progress: █████░░░░ 	51% done
# Fetching data for 1.3.1.83 ...
#
#
# ----> Progress: █████░░░░ 	51% done
# Fetching data for 1.3.1.86 ...
#
#
# ----> Progress: █████░░░░ 	51% done
# Fetching data for 1.3.1.88 ...
#
#
# ----> Progress: █████░░░░ 	51% done
# Fetching data for 1.3.1.9 ...
#
#
# ----> Progress: █████░░░░ 	51% done
# Fetching data for 1.3.1.91 ...
#
#
# ----> Progress: █████░░░░ 	51% done
# Fetching data for 1.3.1.95 ...
#
#
# ----> Progress: █████░░░░ 	51% done
# Fetching data for 1.3.1.98 ...
#
#
# ----> Progress: █████░░░░ 	51% done
# Fetching data for 1.3.2.3 ...
#
#
# ----> Progress: █████░░░░ 	52% done
# Fetching data for 1.3.3.12 ...
#
#
# ----> Progress: █████░░░░ 	52% done
# Fetching data for 1.3.3.15 ...
#
#
# ----> Progress: █████░░░░ 	52% done
# Fetching data for 1.3.3.3 ...
#
#
# ----> Progress: █████░░░░ 	52% done
# Fetching data for 1.3.3.4 ...
#
#
# ----> Progress: █████░░░░ 	52% done
# Fetching data for 1.3.3.5 ...
#
#
# ----> Progress: █████░░░░ 	52% done
# Fetching data for 1.3.3.7 ...
#
#
# ----> Progress: █████░░░░ 	52% done
# Fetching data for 1.3.3.8 ...
#
#
# ----> Progress: █████░░░░ 	53% done
# Fetching data for 1.3.5.1 ...
#
#
# ----> Progress: █████░░░░ 	53% done
# Fetching data for 1.3.5.2 ...
#
#
# ----> Progress: █████░░░░ 	53% done
# Fetching data for 1.3.5.3 ...
#
#
# ----> Progress: █████░░░░ 	53% done
# Fetching data for 1.3.5.4 ...
#
#
# ----> Progress: █████░░░░ 	53% done
# Fetching data for 1.3.5.5 ...
#
#
# ----> Progress: █████░░░░ 	53% done
# Fetching data for 1.3.5.6 ...
#
#
# ----> Progress: █████░░░░ 	53% done
# Fetching data for 1.3.7.11 ...
#
#
# ----> Progress: █████░░░░ 	53% done
# Fetching data for 1.3.7.13 ...
#
#
# ----> Progress: █████░░░░ 	54% done
# Fetching data for 1.3.7.15 ...
#
#
# ----> Progress: █████░░░░ 	54% done
# Fetching data for 1.3.7.8 ...
#
#
# ----> Progress: █████░░░░ 	54% done
# Fetching data for 1.3.7.9 ...
#
#
# ----> Progress: █████░░░░ 	54% done
# Fetching data for 1.3.8.1 ...
#
#
# ----> Progress: █████░░░░ 	54% done
# Fetching data for 1.3.8.10 ...
#
#
# ----> Progress: █████░░░░ 	54% done
# Fetching data for 1.3.8.11 ...
#
#
# ----> Progress: █████░░░░ 	54% done
# Fetching data for 1.3.8.12 ...
#
#
# ----> Progress: █████░░░░ 	54% done
# Fetching data for 1.3.8.13 ...
#
#
# ----> Progress: █████░░░░ 	55% done
# Fetching data for 1.3.8.14 ...
#
#
# ----> Progress: █████░░░░ 	55% done
# Fetching data for 1.3.8.2 ...
#
#
# ----> Progress: █████░░░░ 	55% done
# Fetching data for 1.3.8.3 ...
#
#
# ----> Progress: █████░░░░ 	55% done
# Fetching data for 1.3.8.4 ...
#
#
# ----> Progress: █████░░░░ 	55% done
# Fetching data for 1.3.8.5 ...
#
#
# ----> Progress: █████░░░░ 	55% done
# Fetching data for 1.3.8.6 ...
#
#
# ----> Progress: █████░░░░ 	55% done
# Fetching data for 1.3.8.7 ...
#
#
# ----> Progress: █████░░░░ 	55% done
# Fetching data for 1.3.8.8 ...
#
#
# ----> Progress: █████░░░░ 	56% done
# Fetching data for 1.3.8.9 ...
#
#
# ----> Progress: █████░░░░ 	56% done
# Fetching data for 1.3.98.1 ...
#
#
# ----> Progress: █████░░░░ 	56% done
# Fetching data for 1.3.98.4 ...
#
#
# ----> Progress: █████░░░░ 	56% done
# Fetching data for 1.3.99.12 ...
#
#
# ----> Progress: █████░░░░ 	56% done
# Fetching data for 1.3.99.17 ...
#
#
# ----> Progress: █████░░░░ 	56% done
# Fetching data for 1.3.99.18 ...
#
#
# ----> Progress: █████░░░░ 	56% done
# Fetching data for 1.3.99.19 ...
#
#
# ----> Progress: █████░░░░ 	56% done
# Fetching data for 1.3.99.23 ...
#
#
# ----> Progress: █████░░░░ 	57% done
# Fetching data for 1.3.99.24 ...
#
#
# ----> Progress: █████░░░░ 	57% done
# Fetching data for 1.3.99.27 ...
#
#
# ----> Progress: █████░░░░ 	57% done
# Fetching data for 1.3.99.28 ...
#
#
# ----> Progress: █████░░░░ 	57% done
# Fetching data for 1.3.99.31 ...
#
#
# ----> Progress: █████░░░░ 	57% done
# Fetching data for 1.3.99.32 ...
#
#
# ----> Progress: █████░░░░ 	57% done
# Fetching data for 1.3.99.33 ...
#
#
# ----> Progress: █████░░░░ 	57% done
# Fetching data for 1.3.99.37 ...
#
#
# ----> Progress: █████░░░░ 	57% done
# Fetching data for 1.3.99.38 ...
#
#
# ----> Progress: █████░░░░ 	58% done
# Fetching data for 1.3.99.4 ...
#
#
# ----> Progress: █████░░░░ 	58% done
# Fetching data for 1.3.99.5 ...
#
#
# ----> Progress: █████░░░░ 	58% done
# Fetching data for 1.3.99.6 ...
#
#
# ----> Progress: █████░░░░ 	58% done
# Fetching data for 1.3.99.8 ...
#
#
# ----> Progress: █████░░░░ 	58% done
# Fetching data for 1.3.99.B2 ...
#
#
# ----> Progress: █████░░░░ 	58% done
# Fetching data for 1.4.1.13 ...
#
#
# ----> Progress: █████░░░░ 	58% done
# Fetching data for 1.4.1.14 ...
#
#
# ----> Progress: █████░░░░ 	59% done
# Fetching data for 1.4.1.5 ...
#
#
# ----> Progress: █████░░░░ 	59% done
# Fetching data for 1.4.3.1 ...
#
#
# ----> Progress: █████░░░░ 	59% done
# Fetching data for 1.4.3.10 ...
#
#
# ----> Progress: █████░░░░ 	59% done
# Fetching data for 1.4.3.11 ...
#
#
# ----> Progress: █████░░░░ 	59% done
# Fetching data for 1.4.3.12 ...
#
#
# ----> Progress: █████░░░░ 	59% done
# Fetching data for 1.4.3.14 ...
#
#
# ----> Progress: █████░░░░ 	59% done
# Fetching data for 1.4.3.15 ...
#
#
# ----> Progress: █████░░░░ 	59% done
# Fetching data for 1.4.3.16 ...
#
#
# ----> Progress: ██████░░░░ 	60% done
# Fetching data for 1.4.3.19 ...
#
#
# ----> Progress: ██████░░░░ 	60% done
# Fetching data for 1.4.3.2 ...
#
#
# ----> Progress: ██████░░░░ 	60% done
# Fetching data for 1.4.3.21 ...
#
#
# ----> Progress: ██████░░░░ 	60% done
# Fetching data for 1.4.3.22 ...
#
#
# ----> Progress: ██████░░░░ 	60% done
# Fetching data for 1.4.3.23 ...
#
#
# ----> Progress: ██████░░░░ 	60% done
# Fetching data for 1.4.3.24 ...
#
#
# ----> Progress: ██████░░░░ 	60% done
# Fetching data for 1.4.3.25 ...
#
#
# ----> Progress: ██████░░░░ 	60% done
# Fetching data for 1.4.3.3 ...
#
#
# ----> Progress: ██████░░░ 	61% done
# Fetching data for 1.4.3.4 ...
#
#
# ----> Progress: ██████░░░ 	61% done
# Fetching data for 1.4.3.5 ...
#
#
# ----> Progress: ██████░░░ 	61% done
# Fetching data for 1.4.3.7 ...
#
#
# ----> Progress: ██████░░░ 	61% done
# Fetching data for 1.4.5.1 ...
#
#
# ----> Progress: ██████░░░ 	61% done
# Fetching data for 1.4.7.1 ...
#
#
# ----> Progress: ██████░░░ 	61% done
# Fetching data for 1.4.99.5 ...
#
#
# ----> Progress: ██████░░░ 	61% done
# Fetching data for 1.4.99.6 ...
#
#
# ----> Progress: ██████░░░ 	61% done
# Fetching data for 1.4.99.B3 ...
#
#
# ----> Progress: ██████░░░ 	62% done
# Fetching data for 1.5.1.11 ...
#
#
# ----> Progress: ██████░░░ 	62% done
# Fetching data for 1.5.1.15 ...
#
#
# ----> Progress: ██████░░░ 	62% done
# Fetching data for 1.5.1.19 ...
#
#
# ----> Progress: ██████░░░ 	62% done
# Fetching data for 1.5.1.20 ...
#
#
# ----> Progress: ██████░░░ 	62% done
# Fetching data for 1.5.1.30 ...
#
#
# ----> Progress: ██████░░░ 	62% done
# Fetching data for 1.5.1.34 ...
#
#
# ----> Progress: ██████░░░ 	62% done
# Fetching data for 1.5.1.36 ...
#
#
# ----> Progress: ██████░░░ 	63% done
# Fetching data for 1.5.1.37 ...
#
#
# ----> Progress: ██████░░░ 	63% done
# Fetching data for 1.5.1.38 ...
#
#
# ----> Progress: ██████░░░ 	63% done
# Fetching data for 1.5.1.39 ...
#
#
# ----> Progress: ██████░░░ 	63% done
# Fetching data for 1.5.1.40 ...
#
#
# ----> Progress: ██████░░░ 	63% done
# Fetching data for 1.5.1.41 ...
#
#
# ----> Progress: ██████░░░ 	63% done
# Fetching data for 1.5.1.42 ...
#
#
# ----> Progress: ██████░░░ 	63% done
# Fetching data for 1.5.1.45 ...
#
#
# ----> Progress: ██████░░░ 	63% done
# Fetching data for 1.5.1.46 ...
#
#
# ----> Progress: ██████░░░ 	64% done
# Fetching data for 1.5.3.1 ...
#
#
# ----> Progress: ██████░░░ 	64% done
# Fetching data for 1.5.3.10 ...
#
#
# ----> Progress: ██████░░░ 	64% done
# Fetching data for 1.5.3.12 ...
#
#
# ----> Progress: ██████░░░ 	64% done
# Fetching data for 1.5.3.13 ...
#
#
# ----> Progress: ██████░░░ 	64% done
# Fetching data for 1.5.3.14 ...
#
#
# ----> Progress: ██████░░░ 	64% done
# Fetching data for 1.5.3.16 ...
#
#
# ----> Progress: ██████░░░ 	64% done
# Fetching data for 1.5.3.17 ...
#
#
# ----> Progress: ██████░░░ 	64% done
# Fetching data for 1.5.3.18 ...
#
#
# ----> Progress: ██████░░░ 	65% done
# Fetching data for 1.5.3.19 ...
#
#
# ----> Progress: ██████░░░ 	65% done
# Fetching data for 1.5.3.2 ...
#
#
# ----> Progress: ██████░░░ 	65% done
# Fetching data for 1.5.3.21 ...
#
#
# ----> Progress: ██████░░░ 	65% done
# Fetching data for 1.5.3.22 ...
#
#
# ----> Progress: ██████░░░ 	65% done
# Fetching data for 1.5.3.4 ...
#
#
# ----> Progress: ██████░░░ 	65% done
# Fetching data for 1.5.3.5 ...
#
#
# ----> Progress: ██████░░░ 	65% done
# Fetching data for 1.5.3.6 ...
#
#
# ----> Progress: ██████░░░ 	65% done
# Fetching data for 1.5.3.7 ...
#
#
# ----> Progress: ██████░░░ 	66% done
# Fetching data for 1.5.5.1 ...
#
#
# ----> Progress: ██████░░░ 	66% done
# Fetching data for 1.5.5.2 ...
#
#
# ----> Progress: ██████░░░ 	66% done
# Fetching data for 1.5.5.3 ...
#
#
# ----> Progress: ██████░░░ 	66% done
# Fetching data for 1.5.7.1 ...
#
#
# ----> Progress: ██████░░░ 	66% done
# Fetching data for 1.5.7.2 ...
#
#
# ----> Progress: ██████░░░ 	66% done
# Fetching data for 1.5.8.1 ...
#
#
# ----> Progress: ██████░░░ 	66% done
# Fetching data for 1.5.8.2 ...
#
#
# ----> Progress: ██████░░░ 	66% done
# Fetching data for 1.5.8.3 ...
#
#
# ----> Progress: ██████░░░ 	67% done
# Fetching data for 1.5.8.4 ...
#
#
# ----> Progress: ██████░░░ 	67% done
# Fetching data for 1.5.98.3 ...
#
#
# ----> Progress: ██████░░░ 	67% done
# Fetching data for 1.5.99.12 ...
#
#
# ----> Progress: ██████░░░ 	67% done
# Fetching data for 1.5.99.13 ...
#
#
# ----> Progress: ██████░░░ 	67% done
# Fetching data for 1.5.99.14 ...
#
#
# ----> Progress: ██████░░░ 	67% done
# Fetching data for 1.5.99.15 ...
#
#
# ----> Progress: ██████░░░ 	67% done
# Fetching data for 1.5.99.3 ...
#
#
# ----> Progress: ██████░░░ 	67% done
# Fetching data for 1.5.99.4 ...
#
#
# ----> Progress: ██████░░░ 	68% done
# Fetching data for 1.5.99.5 ...
#
#
# ----> Progress: ██████░░░ 	68% done
# Fetching data for 1.5.99.6 ...
#
#
# ----> Progress: ██████░░░ 	68% done
# Fetching data for 1.5.99.B2 ...
#
#
# ----> Progress: ██████░░░ 	68% done
# Fetching data for 1.5.99.B4 ...
#
#
# ----> Progress: ██████░░░ 	68% done
# Fetching data for 1.6.1.1 ...
#
#
# ----> Progress: ██████░░░ 	68% done
# Fetching data for 1.6.1.3 ...
#
#
# ----> Progress: ██████░░░ 	68% done
# Fetching data for 1.6.1.4 ...
#
#
# ----> Progress: ██████░░░ 	68% done
# Fetching data for 1.6.2.2 ...
#
#
# ----> Progress: ██████░░░ 	69% done
# Fetching data for 1.6.2.4 ...
#
#
# ----> Progress: ██████░░░ 	69% done
# Fetching data for 1.6.2.5 ...
#
#
# ----> Progress: ██████░░░ 	69% done
# Fetching data for 1.6.2.6 ...
#
#
# ----> Progress: ██████░░░ 	69% done
# Fetching data for 1.6.3.1 ...
#
#
# ----> Progress: ██████░░░ 	69% done
# Fetching data for 1.6.3.2 ...
#
#
# ----> Progress: ██████░░░ 	69% done
# Fetching data for 1.6.3.3 ...
#
#
# ----> Progress: ██████░░░ 	69% done
# Fetching data for 1.6.3.4 ...
#
#
# ----> Progress: ██████░░░ 	69% done
# Fetching data for 1.6.3.5 ...
#
#
# ----> Progress: ███████░░░ 	70% done
# Fetching data for 1.6.5.10 ...
#
#
# ----> Progress: ███████░░░ 	70% done
# Fetching data for 1.6.5.11 ...
#
#
# ----> Progress: ███████░░░ 	70% done
# Fetching data for 1.6.5.12 ...
#
#
# ----> Progress: ███████░░░ 	70% done
# Fetching data for 1.6.5.2 ...
#
#
# ----> Progress: ███████░░░ 	70% done
# Fetching data for 1.6.5.4 ...
#
#
# ----> Progress: ███████░░░ 	70% done
# Fetching data for 1.6.5.5 ...
#
#
# ----> Progress: ███████░░░ 	70% done
# Fetching data for 1.6.5.6 ...
#
#
# ----> Progress: ███████░░░ 	70% done
# Fetching data for 1.6.5.7 ...
#
#
# ----> Progress: ███████░░ 	71% done
# Fetching data for 1.6.5.9 ...
#
#
# ----> Progress: ███████░░ 	71% done
# Fetching data for 1.6.99.1 ...
#
#
# ----> Progress: ███████░░ 	71% done
# Fetching data for 1.6.99.3 ...
#
#
# ----> Progress: ███████░░ 	71% done
# Fetching data for 1.7.1.1 ...
#
#
# ----> Progress: ███████░░ 	71% done
# Fetching data for 1.7.1.10 ...
#
#
# ----> Progress: ███████░░ 	71% done
# Fetching data for 1.7.1.15 ...
#
#
# ----> Progress: ███████░░ 	72% done
# Fetching data for 1.7.1.16 ...
#
#
# ----> Progress: ███████░░ 	72% done
# Fetching data for 1.7.1.17 ...
#
#
# ----> Progress: ███████░░ 	72% done
# Fetching data for 1.7.1.2 ...
#
#
# ----> Progress: ███████░░ 	72% done
# Fetching data for 1.7.1.3 ...
#
#
# ----> Progress: ███████░░ 	72% done
# Fetching data for 1.7.1.4 ...
#
#
# ----> Progress: ███████░░ 	72% done
# Fetching data for 1.7.1.5 ...
#
#
# ----> Progress: ███████░░ 	72% done
# Fetching data for 1.7.1.6 ...
#
#
# ----> Progress: ███████░░ 	72% done
# Fetching data for 1.7.1.B1 ...
#
#
# ----> Progress: ███████░░ 	73% done
# Fetching data for 1.7.1.B3 ...
#
#
# ----> Progress: ███████░░ 	73% done
# Fetching data for 1.7.2.2 ...
#
#
# ----> Progress: ███████░░ 	73% done
# Fetching data for 1.7.2.3 ...
#
#
# ----> Progress: ███████░░ 	73% done
# Fetching data for 1.7.3.1 ...
#
#
# ----> Progress: ███████░░ 	73% done
# Fetching data for 1.7.3.5 ...
#
#
# ----> Progress: ███████░░ 	73% done
# Fetching data for 1.7.5.1 ...
#
#
# ----> Progress: ███████░░ 	73% done
# Fetching data for 1.7.7.1 ...
#
#
# ----> Progress: ███████░░ 	73% done
# Fetching data for 1.7.7.2 ...
#
#
# ----> Progress: ███████░░ 	74% done
# Fetching data for 1.7.99.1 ...
#
#
# ----> Progress: ███████░░ 	74% done
# Fetching data for 1.8.1.10 ...
#
#
# ----> Progress: ███████░░ 	74% done
# Fetching data for 1.8.1.11 ...
#
#
# ----> Progress: ███████░░ 	74% done
# Fetching data for 1.8.1.12 ...
#
#
# ----> Progress: ███████░░ 	74% done
# Fetching data for 1.8.1.13 ...
#
#
# ----> Progress: ███████░░ 	74% done
# Fetching data for 1.8.1.14 ...
#
#
# ----> Progress: ███████░░ 	74% done
# Fetching data for 1.8.1.15 ...
#
#
# ----> Progress: ███████░░ 	75% done
# Fetching data for 1.8.1.16 ...
#
#
# ----> Progress: ███████░░ 	75% done
# Fetching data for 1.8.1.18 ...
#
#
# ----> Progress: ███████░░ 	75% done
# Fetching data for 1.8.1.19 ...
#
#
# ----> Progress: ███████░░ 	75% done
# Fetching data for 1.8.1.2 ...
#
#
# ----> Progress: ███████░░ 	75% done
# Fetching data for 1.8.1.20 ...
#
#
# ----> Progress: ███████░░ 	75% done
# Fetching data for 1.8.1.4 ...
#
#
# ----> Progress: ███████░░ 	75% done
# Fetching data for 1.8.1.5 ...
#
#
# ----> Progress: ███████░░ 	75% done
# Fetching data for 1.8.1.7 ...
#
#
# ----> Progress: ███████░░ 	75% done
# Fetching data for 1.8.1.8 ...
#
#
# ----> Progress: ███████░░ 	76% done
# Fetching data for 1.8.1.9 ...
#
#
# ----> Progress: ███████░░ 	76% done
# Fetching data for 1.8.1.B4 ...
#
#
# ----> Progress: ███████░░ 	76% done
# Fetching data for 1.8.2.1 ...
#
#
# ----> Progress: ███████░░ 	76% done
# Fetching data for 1.8.2.3 ...
#
#
# ----> Progress: ███████░░ 	76% done
# Fetching data for 1.8.3.2 ...
#
#
# ----> Progress: ███████░░ 	76% done
# Fetching data for 1.8.3.3 ...
#
#
# ----> Progress: ███████░░ 	76% done
# Fetching data for 1.8.3.5 ...
#
#
# ----> Progress: ███████░░ 	77% done
# Fetching data for 1.8.3.6 ...
#
#
# ----> Progress: ███████░░ 	77% done
# Fetching data for 1.8.4.10 ...
#
#
# ----> Progress: ███████░░ 	77% done
# Fetching data for 1.8.5.1 ...
#
#
# ----> Progress: ███████░░ 	77% done
# Fetching data for 1.8.5.4 ...
#
#
# ----> Progress: ███████░░ 	77% done
# Fetching data for 1.8.5.8 ...
#
#
# ----> Progress: ███████░░ 	77% done
# Fetching data for 1.8.7.1 ...
#
#
# ----> Progress: ███████░░ 	77% done
# Fetching data for 1.8.7.3 ...
#
#
# ----> Progress: ███████░░ 	77% done
# Fetching data for 1.8.98.1 ...
#
#
# ----> Progress: ███████░░ 	78% done
# Fetching data for 1.8.98.5 ...
#
#
# ----> Progress: ███████░░ 	78% done
# Fetching data for 1.8.99.2 ...
#
#
# ----> Progress: ███████░░ 	78% done
# Fetching data for 1.97.1.1 ...
#
#
# ----> Progress: ███████░░ 	78% done
# Fetching data for 1.97.1.4 ...
#
#
# ----> Progress: ███████░░ 	78% done
# Fetching data for 2.1.1.13 ...
#
#
# ----> Progress: ███████░░ 	78% done
# Fetching data for 2.1.1.148 ...
#
#
# ----> Progress: ███████░░ 	78% done
# Fetching data for 2.1.1.190 ...
#
#
# ----> Progress: ███████░░ 	79% done
# Fetching data for 2.1.1.21 ...
#
#
# ----> Progress: ███████░░ 	79% done
# Fetching data for 2.1.1.229 ...
#
#
# ----> Progress: ███████░░ 	79% done
# Fetching data for 2.1.1.343 ...
#
#
# ----> Progress: ███████░░ 	79% done
# Fetching data for 2.1.1.349 ...
#
#
# ----> Progress: ███████░░ 	79% done
# Fetching data for 2.1.1.6 ...
#
#
# ----> Progress: ███████░░ 	79% done
# Fetching data for 2.1.1.74 ...
#
#
# ----> Progress: ███████░░ 	79% done
# Fetching data for 2.1.1.B117 ...
#
#
# ----> Progress: ███████░░ 	79% done
# Fetching data for 2.2.1.6 ...
#
#
# ----> Progress: ████████░░ 	80% done
# Fetching data for 2.3.1.118 ...
#
#
# ----> Progress: ████████░░ 	80% done
# Fetching data for 2.3.1.5 ...
#
#
# ----> Progress: ████████░░ 	80% done
# Fetching data for 2.3.1.67 ...
#
#
# ----> Progress: ████████░░ 	80% done
# Fetching data for 2.3.1.86 ...
#
#
# ----> Progress: ████████░░ 	80% done
# Fetching data for 2.3.2.5 ...
#
#
# ----> Progress: ████████░░ 	80% done
# Fetching data for 2.4.1.1 ...
#
#
# ----> Progress: ████████░░ 	80% done
# Fetching data for 2.4.1.207 ...
#
#
# ----> Progress: ████████░░ 	80% done
# Fetching data for 2.5.1.129 ...
#
#
# ----> Progress: ████████░ 	81% done
# Fetching data for 2.5.1.15 ...
#
#
# ----> Progress: ████████░ 	81% done
# Fetching data for 2.5.1.17 ...
#
#
# ----> Progress: ████████░ 	81% done
# Fetching data for 2.5.1.26 ...
#
#
# ----> Progress: ████████░ 	81% done
# Fetching data for 2.5.1.46 ...
#
#
# ----> Progress: ████████░ 	81% done
# Fetching data for 2.5.1.78 ...
#
#
# ----> Progress: ████████░ 	81% done
# Fetching data for 2.5.1.9 ...
#
#
# ----> Progress: ████████░ 	81% done
# Fetching data for 2.5.1.94 ...
#
#
# ----> Progress: ████████░ 	82% done
# Fetching data for 2.6.1.114 ...
#
#
# ----> Progress: ████████░ 	82% done
# Fetching data for 2.7.1.161 ...
#
#
# ----> Progress: ████████░ 	82% done
# Fetching data for 2.7.1.180 ...
#
#
# ----> Progress: ████████░ 	82% done
# Fetching data for 2.7.1.20 ...
#
#
# ----> Progress: ████████░ 	82% done
# Fetching data for 2.7.1.25 ...
#
#
# ----> Progress: ████████░ 	82% done
# Fetching data for 2.7.1.26 ...
#
#
# ----> Progress: ████████░ 	82% done
# Fetching data for 2.7.1.29 ...
#
#
# ----> Progress: ████████░ 	82% done
# Fetching data for 2.7.1.42 ...
#
#
# ----> Progress: ████████░ 	83% done
# Fetching data for 2.7.10.2 ...
#
#
# ----> Progress: ████████░ 	83% done
# Fetching data for 2.7.11.1 ...
#
#
# ----> Progress: ████████░ 	83% done
# Fetching data for 2.7.11.19 ...
#
#
# ----> Progress: ████████░ 	83% done
# Fetching data for 2.7.11.21 ...
#
#
# ----> Progress: ████████░ 	83% done
# Fetching data for 2.7.11.31 ...
#
#
# ----> Progress: ████████░ 	83% done
# Fetching data for 2.7.13.3 ...
#
#
# ----> Progress: ████████░ 	83% done
# Fetching data for 2.7.6.1 ...
#
#
# ----> Progress: ████████░ 	83% done
# Fetching data for 2.7.6.3 ...
#
#
# ----> Progress: ████████░ 	84% done
# Fetching data for 2.7.7.19 ...
#
#
# ----> Progress: ████████░ 	84% done
# Fetching data for 2.7.7.2 ...
#
#
# ----> Progress: ████████░ 	84% done
# Fetching data for 2.7.7.27 ...
#
#
# ----> Progress: ████████░ 	84% done
# Fetching data for 2.7.7.6 ...
#
#
# ----> Progress: ████████░ 	84% done
# Fetching data for 2.7.7.85 ...
#
#
# ----> Progress: ████████░ 	84% done
# Fetching data for 2.7.8.28 ...
#
#
# ----> Progress: ████████░ 	84% done
# Fetching data for 2.8.1.5 ...
#
#
# ----> Progress: ████████░ 	85% done
# Fetching data for 2.8.1.6 ...
#
#
# ----> Progress: ████████░ 	85% done
# Fetching data for 2.8.2.1 ...
#
#
# ----> Progress: ████████░ 	85% done
# Fetching data for 3.1.1.43 ...
#
#
# ----> Progress: ████████░ 	85% done
# Fetching data for 3.1.1.7 ...
#
#
# ----> Progress: ████████░ 	85% done
# Fetching data for 3.1.1.8 ...
#
#
# ----> Progress: ████████░ 	85% done
# Fetching data for 3.1.2.2 ...
#
#
# ----> Progress: ████████░ 	85% done
# Fetching data for 3.1.2.20 ...
#
#
# ----> Progress: ████████░ 	85% done
# Fetching data for 3.1.3.1 ...
#
#
# ----> Progress: ████████░ 	86% done
# Fetching data for 3.1.3.100 ...
#
#
# ----> Progress: ████████░ 	86% done
# Fetching data for 3.1.3.102 ...
#
#
# ----> Progress: ████████░ 	86% done
# Fetching data for 3.1.3.104 ...
#
#
# ----> Progress: ████████░ 	86% done
# Fetching data for 3.1.3.11 ...
#
#
# ----> Progress: ████████░ 	86% done
# Fetching data for 3.1.3.2 ...
#
#
# ----> Progress: ████████░ 	86% done
# Fetching data for 3.1.3.43 ...
#
#
# ----> Progress: ████████░ 	86% done
# Fetching data for 3.1.3.48 ...
#
#
# ----> Progress: ████████░ 	86% done
# Fetching data for 3.1.3.5 ...
#
#
# ----> Progress: ████████░ 	87% done
# Fetching data for 3.1.3.8 ...
#
#
# ----> Progress: ████████░ 	87% done
# Fetching data for 3.1.4.1 ...
#
#
# ----> Progress: ████████░ 	87% done
# Fetching data for 3.1.4.17 ...
#
#
# ----> Progress: ████████░ 	87% done
# Fetching data for 3.1.8.1 ...
#
#
# ----> Progress: ████████░ 	87% done
# Fetching data for 3.13.1.4 ...
#
#
# ----> Progress: ████████░ 	87% done
# Fetching data for 3.2.1.20 ...
#
#
# ----> Progress: ████████░ 	87% done
# Fetching data for 3.2.2.4 ...
#
#
# ----> Progress: ████████░ 	87% done
# Fetching data for 3.3.1.1 ...
#
#
# ----> Progress: ████████░ 	88% done
# Fetching data for 3.5.1.11 ...
#
#
# ----> Progress: ████████░ 	89% done
# Fetching data for 3.5.1.24 ...
#
#
# ----> Progress: ████████░ 	89% done
# Fetching data for 3.5.1.48 ...
#
#
# ----> Progress: ████████░ 	89% done
# Fetching data for 3.5.1.88 ...
#
#
# ----> Progress: ████████░ 	89% done
# Fetching data for 3.5.2.6 ...
#
#
# ----> Progress: ████████░ 	89% done
# Fetching data for 3.5.4.18 ...
#
#
# ----> Progress: ████████░ 	89% done
# Fetching data for 3.5.4.26 ...
#
#
# ----> Progress: ████████░ 	89% done
# Fetching data for 3.5.99.1 ...
#
#
# ----> Progress: █████████░ 	90% done
# Fetching data for 3.6.1.13 ...
#
#
# ----> Progress: █████████░ 	90% done
# Fetching data for 3.6.1.15 ...
#
#
# ----> Progress: █████████░ 	90% done
# Fetching data for 3.6.1.18 ...
#
#
# ----> Progress: █████████░ 	90% done
# Fetching data for 3.6.1.21 ...
#
#
# ----> Progress: █████████░ 	90% done
# Fetching data for 3.6.1.22 ...
#
#
# ----> Progress: █████████░ 	90% done
# Fetching data for 3.6.1.5 ...
#
#
# ----> Progress: █████████░ 	90% done
# Fetching data for 3.6.1.53 ...
#
#
# ----> Progress: █████████░ 	90% done
# Fetching data for 3.6.1.9 ...
#
#
# ----> Progress: █████████ 	91% done
# Fetching data for 3.6.2.1 ...
#
#
# ----> Progress: █████████ 	91% done
# Fetching data for 3.7.1.11 ...
#
#
# ----> Progress: █████████ 	91% done
# Fetching data for 4.1.1.102 ...
#
#
# ----> Progress: █████████ 	91% done
# Fetching data for 4.1.1.106 ...
#
#
# ----> Progress: █████████ 	91% done
# Fetching data for 4.1.1.17 ...
#
#
# ----> Progress: █████████ 	91% done
# Fetching data for 4.1.1.36 ...
#
#
# ----> Progress: █████████ 	91% done
# Fetching data for 4.1.1.47 ...
#
#
# ----> Progress: █████████ 	91% done
# Fetching data for 4.1.1.50 ...
#
#
# ----> Progress: █████████ 	92% done
# Fetching data for 4.1.1.74 ...
#
#
# ----> Progress: █████████ 	92% done
# Fetching data for 4.1.1.98 ...
#
#
# ----> Progress: █████████ 	92% done
# Fetching data for 4.1.2.10 ...
#
#
# ----> Progress: █████████ 	92% done
# Fetching data for 4.1.2.32 ...
#
#
# ----> Progress: █████████ 	92% done
# Fetching data for 4.1.2.47 ...
#
#
# ----> Progress: █████████ 	92% done
# Fetching data for 4.1.2.49 ...
#
#
# ----> Progress: █████████ 	92% done
# Fetching data for 4.1.99.11 ...
#
#
# ----> Progress: █████████ 	92% done
# Fetching data for 4.1.99.13 ...
#
#
# ----> Progress: █████████ 	93% done
# Fetching data for 4.1.99.3 ...
#
#
# ----> Progress: █████████ 	93% done
# Fetching data for 4.2.1.1 ...
#
#
# ----> Progress: █████████ 	93% done
# Fetching data for 4.2.1.120 ...
#
#
# ----> Progress: █████████ 	93% done
# Fetching data for 4.2.1.167 ...
#
#
# ----> Progress: █████████ 	93% done
# Fetching data for 4.2.1.17 ...
#
#
# ----> Progress: █████████ 	93% done
# Fetching data for 4.2.1.48 ...
#
#
# ----> Progress: █████████ 	93% done
# Fetching data for 4.2.1.53 ...
#
#
# ----> Progress: █████████ 	93% done
# Fetching data for 4.2.1.54 ...
#
#
# ----> Progress: █████████ 	94% done
# Fetching data for 4.2.1.B25 ...
#
#
# ----> Progress: █████████ 	94% done
# Fetching data for 4.2.1.B26 ...
#
#
# ----> Progress: █████████ 	94% done
# Fetching data for 4.2.3.5 ...
#
#
# ----> Progress: █████████ 	94% done
# Fetching data for 4.3.1.32  ...
#
#
# ----> Progress: █████████ 	94% done
# Fetching data for 4.3.3.5 ...
#
#
# ----> Progress: █████████ 	94% done
# Fetching data for 4.3.3.7 ...
#
#
# ----> Progress: █████████ 	94% done
# Fetching data for 4.4.1.17 ...
#
#
# ----> Progress: █████████ 	94% done
# Fetching data for 4.6.1.15 ...
#
#
# ----> Progress: █████████ 	95% done
# Fetching data for 4.99.1.2 ...
#
#
# ----> Progress: █████████ 	95% done
# Fetching data for 4.99.1.5 ...
#
#
# ----> Progress: █████████ 	95% done
# Fetching data for 4.99.1.7 ...
#
#
# ----> Progress: █████████ 	95% done
# Fetching data for 5.1.1.1 ...
#
#
# ----> Progress: █████████ 	95% done
# Fetching data for 5.1.1.17 ...
#
#
# ----> Progress: █████████ 	95% done
# Fetching data for 5.1.1.3 ...
#
#
# ----> Progress: █████████ 	95% done
# Fetching data for 5.1.1.8 ...
#
#
# ----> Progress: █████████ 	95% done
# Fetching data for 5.1.3.20 ...
#
#
# ----> Progress: █████████ 	96% done
# Fetching data for 5.2.1.13 ...
#
#
# ----> Progress: █████████ 	96% done
# Fetching data for 5.2.1.5 ...
#
#
# ----> Progress: █████████ 	96% done
# Fetching data for 5.3.1.12 ...
#
#
# ----> Progress: █████████ 	96% done
# Fetching data for 5.3.1.8 ...
#
#
# ----> Progress: █████████ 	96% done
# Fetching data for 5.3.3.13 ...
#
#
# ----> Progress: █████████ 	96% done
# Fetching data for 5.3.3.2 ...
#
#
# ----> Progress: █████████ 	96% done
# Fetching data for 5.3.3.3 ...
#
#
# ----> Progress: █████████ 	96% done
# Fetching data for 5.3.3.B2 ...
#
#
# ----> Progress: █████████ 	97% done
# Fetching data for 5.3.4.1 ...
#
#
# ----> Progress: █████████ 	97% done
# Fetching data for 5.3.99.3 ...
#
#
# ----> Progress: █████████ 	97% done
# Fetching data for 5.3.99.8 ...
#
#
# ----> Progress: █████████ 	97% done
# Fetching data for 5.4.3.3 ...
#
#
# ----> Progress: █████████ 	97% done
# Fetching data for 5.4.99.9 ...
#
#
# ----> Progress: █████████ 	97% done
# Fetching data for 5.5.1.18 ...
#
#
# ----> Progress: █████████ 	97% done
# Fetching data for 5.5.1.19 ...
#
#
# ----> Progress: █████████ 	97% done
# Fetching data for 5.5.1.20 ...
#
#
# ----> Progress: █████████ 	98% done
# Fetching data for 5.6.2.1 ...
#
#
# ----> Progress: █████████ 	98% done
# Fetching data for 6.2.1.1 ...
#
#
# ----> Progress: █████████ 	98% done
# Fetching data for 6.2.1.3 ...
#
#
# ----> Progress: █████████ 	98% done
# Fetching data for 6.2.1.41 ...
#
#
# ----> Progress: █████████ 	98% done
# Fetching data for 6.2.1.42 ...
#
#
# ----> Progress: █████████ 	98% done
# Fetching data for 6.2.1.49 ...
#
#
# ----> Progress: █████████ 	98% done
# Fetching data for 6.2.1.50 ...
#
#
# ----> Progress: █████████ 	98% done
# Fetching data for 6.2.1.51 ...
#
#
# ----> Progress: █████████ 	99% done
# Fetching data for 6.2.1.57 ...
#
#
# ----> Progress: █████████ 	99% done
# Fetching data for 6.3.2.5 ...
#
#
# ----> Progress: █████████ 	99% done
# Fetching data for 6.3.4.18 ...
#
#
# ----> Progress: █████████ 	99% done
# Fetching data for 6.3.4.4 ...
#
#
# ----> Progress: █████████ 	99% done
# Fetching data for 7.1.1.1 ...
#
#
# ----> Progress: █████████ 	99% done
# Fetching data for 7.1.1.2 ...
#
#
# ----> Progress: █████████ 	99% done
# Fetching data for 7.2.1.2 ...
#
#
# ----> Progress: ██████████ 	100% done
# Fetching data for 7.2.4.5 ...
#
#
# ----> Progress: ██████████ 	100% done
# Fetching data for 7.4.2.3 ...
#
#
# ----> Progress: ██████████ 	100% done
# Fetching data for 7.4.2.5 ...
#
#
# ----> Progress: ██████████ 	100% done
# Fetching data for 7.6.2.2 ...
#
#
# ----> Progress: ██████████ 	100% done
#
# Successfully written out 781 results to "export/brenda_new_export.json"

# %% [markdown]
# # Exploration:

# %%
len(db)
# Out:
# 781

# %%
db['2.5.1.9']
# Out:
# {'SYSNAME': '6,7-dimethyl-8-(1-D-ribityl)lumazine:6,7-dimethyl-8-(1-D-ribityl)lumazine 2,3-butanediyltransferase',
#  'REACTIONS': ['2 6,7-dimethyl-8-(1-D-ribityl)lumazine = riboflavin + 4-(1-D-ribitylamino)-5-amino-2,6-dihydroxypyrimidine'],
#  'SYNONYMS': ['RibD',
#   'heavy riboflavin synthase',
#   'light riboflavin synthase',
#   'lumazine synthase/riboflavin synthase complex',
#   'riboflavin synthase',
#   'riboflavin synthetase',
#   'riboflavine synthase',
#   'riboflavine synthetase',
#   'synthase, riboflavin'],
#  'SUBSTRATE': ['2 6,7-dimethyl-8-ribityllumazine',
#   '6,7-dimethyl-8-(1-D-ribityl)lumazine',
#   "6,7-dimethyl-8-[1'-(5'-deoxy-D-ribityl)]lumazine",
#   '6,7-dimethyl-8-ribityllumazine',
#   'more'],
#  'PRODUCT': ["4-(1'-D-ribitylamino)-5-amino-2,6-dihydroxypyrimidine",
#   '4-(1-D-ribitylamino)-5-amino-2,6-dihydroxypyrimidine',
#   "5'-deoxyriboflavin",
#   '5-amino-6-ribitylamino-2,4(1H,3H)-pyrimidine-dione',
#   '5-amino-6-ribitylamino-2,4-(1H,3H)-pyrimidinedione',
#   '?',
#   'a compound related to 4-ribitylamino-2,5,6-trihydroxypyrimidine',
#   'riboflavin'],
#  'PDB': ['1hze',
#   '1i18',
#   '1i8d',
#   '1kzl',
#   '1pkv',
#   '2b98',
#   '2b99',
#   '4y7j',
#   '4y7k',
#   '5im5'],
#  'EC_NUMBER': '2.5.1.9'}

# %%
# dataframe to easily work with
df = pd.DataFrame(db).T

# %% [markdown]
# #### Discuss: Enzymes that have the same sysname

# %%
list_of_sysnames = [previous_db[ec]['SYSNAME'] for ec in sorted(previous_db.keys())]
duplicates = [item for item in list_of_sysnames if list_of_sysnames.count(item) > 1]
[print(ec + " \t|\t " + previous_db[ec]['SYSNAME']) for ec in previous_db.keys() if previous_db[ec]['SYSNAME'] in duplicates]
pass
# Out:
# 1.14.13.B1 	|	 (-)-bornane-2,5-dione,FMNH2:oxygen oxidoreductase (1,2-lactonizing)
# 1.14.14.155 	|	 (-)-bornane-2,5-dione,FMNH2:oxygen oxidoreductase (1,2-lactonizing)
# 1.3.5.1 	|	 succinate:quinone oxidoreductase
# 1.3.5.4 	|	 succinate:quinone oxidoreductase
# 1.6.5.9 	|	 NADH:ubiquinone oxidoreductase
# 4.2.1.167 	|	 (R)-2-hydroxyglutaryl-CoA hydro-lyase ((E)-glutaconyl-CoA-forming)
# 4.2.1.B26 	|	 (R)-2-hydroxyglutaryl-CoA hydro-lyase ((E)-glutaconyl-CoA-forming)
# 7.1.1.2 	|	 NADH:ubiquinone oxidoreductase
