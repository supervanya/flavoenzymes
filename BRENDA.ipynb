# %%
import pandas as pd
from io import StringIO
import requests

columns = ['EC Number', 'Recommended Name', 'Synonyms', 'Commentary','Discard']

def search_brenda(term):
    header = {
      "User-Agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.75 Safari/537.36",
      "X-Requested-With": "XMLHttpRequest"
    }
    url = f'https://www.brenda-enzymes.org/result_download.php?a=9&RN=&RNV=1&os=1&pt=&FNV=&tt=&SYN=&Textmining=&T[0]=2&T[1]=2&W[2]={term}&T[2]=2&nolimit=1'    
    r = requests.get(url, headers=header)
    df = pd.read_csv(StringIO(r.text), sep='\t', header=None, names=columns)
    return df

# %%
all_df = None

terms = ['FAD','FMN']

for term in terms:
    df = search_brenda(term)
    if all_df is None:
        all_df = df
    else:
        all_df.append(df)

# %%
all_df
# Out:
#      EC Number                                   Recommended Name  \
# 0      1.1.1.1                              alcohol dehydrogenase
# 1    1.1.1.215                          gluconate 2-dehydrogenase
# 2    1.1.1.289                                  sorbose reductase
# 3    1.1.1.306           S-(hydroxymethyl)mycothiol dehydrogenase
# 4     1.1.1.35                    3-hydroxyacyl-CoA dehydrogenase
# ..         ...                                                ...
# 97    6.2.1.42               3-oxocholest-4-en-26-oate-CoA ligase
# 98    6.2.1.49   long-chain fatty acid adenylyltransferase FadD28
# 99    6.2.1.50       4-hydroxybenzoate adenylyltransferase FadD22
# 100   6.2.1.51  4-hydroxyphenylalkanoate adenylyltransferase F...
# 101    6.3.4.4                          adenylosuccinate synthase
#
#                                               Synonyms Commentary  Discard
# 0                                                PFADH          -      NaN
# 1                                             FAD-GADH          -      NaN
# 2               FAD-dependent D-sorbitol dehydrogenase          -      NaN
# 3                                                mFADH          -      NaN
# 4                                   FadB; FadB'; FadB2          -      NaN
# ..                                                 ...        ...      ...
# 97                                              fadD19          -      NaN
# 98   fadD28; long-chain fatty acid adenylyltransfer...          -      NaN
# 99   4-hydroxybenzoate adenylyltransferase FadD22; ...          -      NaN
# 100  4-hydroxyphenylalkanoate adenylyltransferase F...          -      NaN
# 101                                             PfAdSS          -      NaN
#
# [102 rows x 5 columns]

# %%
df = search_brenda('FAD')
df
# Out:
#      EC Number                                   Recommended Name  \
# 0      1.1.1.1                              alcohol dehydrogenase
# 1    1.1.1.215                          gluconate 2-dehydrogenase
# 2    1.1.1.289                                  sorbose reductase
# 3    1.1.1.306           S-(hydroxymethyl)mycothiol dehydrogenase
# 4     1.1.1.35                    3-hydroxyacyl-CoA dehydrogenase
# ..         ...                                                ...
# 97    6.2.1.42               3-oxocholest-4-en-26-oate-CoA ligase
# 98    6.2.1.49   long-chain fatty acid adenylyltransferase FadD28
# 99    6.2.1.50       4-hydroxybenzoate adenylyltransferase FadD22
# 100   6.2.1.51  4-hydroxyphenylalkanoate adenylyltransferase F...
# 101    6.3.4.4                          adenylosuccinate synthase
#
#                                               Synonyms Commentary  Discard
# 0                                                PFADH          -      NaN
# 1                                             FAD-GADH          -      NaN
# 2               FAD-dependent D-sorbitol dehydrogenase          -      NaN
# 3                                                mFADH          -      NaN
# 4                                   FadB; FadB'; FadB2          -      NaN
# ..                                                 ...        ...      ...
# 97                                              fadD19          -      NaN
# 98   fadD28; long-chain fatty acid adenylyltransfer...          -      NaN
# 99   4-hydroxybenzoate adenylyltransferase FadD22; ...          -      NaN
# 100  4-hydroxyphenylalkanoate adenylyltransferase F...          -      NaN
# 101                                             PfAdSS          -      NaN
#
# [102 rows x 5 columns]
