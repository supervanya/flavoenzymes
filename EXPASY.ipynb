# %%
# Getting cofactors from https://enzyme.expasy.org/

# %%
from cache import cached_reqest

# %%
cofactors_list = ['flavin', 'FMN', 'FAD', 'Flavoprotein']

# %%
def get_cofactor_url(term):
    return f'https://enzyme.expasy.org/cgi-bin/enzyme/enzyme-search-cf?{term}'

# %%
for term in cofactors_list:
    url = get_cofactor_url(term);
    response = cached_reqest(url)
# Out:
# Getting cached data...
# https://enzyme.expasy.org/cgi-bin/enzyme/enzyme-search-cf?flavin
# Getting cached data...
# https://enzyme.expasy.org/cgi-bin/enzyme/enzyme-search-cf?FMN
# Getting cached data...
# https://enzyme.expasy.org/cgi-bin/enzyme/enzyme-search-cf?FAD
# Getting cached data...
# https://enzyme.expasy.org/cgi-bin/enzyme/enzyme-search-cf?Flavoprotein

# %%
r = cached_reqest('https://enzyme.expasy.org/cgi-bin/enzyme/enzyme-search-cf?FAD')
# Out:
# Getting cached data...
# https://enzyme.expasy.org/cgi-bin/enzyme/enzyme-search-cf?FAD

# %%
r.split('\n             ')
# Out:
# ['<!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">\n<html lang="en-US" prefix="bioschema: http://bioschemas.org/">\n  <head>\n    <meta http-equiv="Content-Type" content="text/html;charset=iso-8859-1"><!-- automatically added by Apache -->\n<script type="application/ld+json">{\n\t\t"@context" : [ "https://schema.org/" ],\n\t\t"@type" : "Organization",\n\t\t"url" : "https://enzyme.expasy.org",\n  \t\t"name": "ENZYME"\n\t\t, "logo": "https://enzyme.expasy.org//images/expasy_logos/sprot1.gif"\n\t\t, "memberof" : {\n\t\t\t\t"@type" : "NGO",\n\t\t\t\t"name"  : "SIB Swiss Institute of Bioinformatics",\n\t\t\t\t"url"   : "https://sib.swiss/"\n\t\t\t        }\n\t\t, "parentOrganization" : \n\t\t\t\t{\n\t\t\t\t"@type" : "Organization",',
#  '                   "name"  : "ExPASy",',
# ...
